# %%
import pandas as pd
import nltk
nltk.download('wordnet')
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
import nbformat
import plotly
import bokeh
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/forrestwilliams/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/forrestwilliams/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
mgp_tweets = pd.read_csv('data/mgp_full_tweets.csv')
deluzio_tweets = pd.read_csv('data/Deluzio_Tweets.csv')

# %%
# Importing my previous notebook 
from Topic_Modeling import glove_model, preprocess_text, insert_line_breaks
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/forrestwilliams/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/forrestwilliams/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Topic 1:
# https | joe | kent | pro | election | ballot | like | campaign | doors | join | volunteers | volunteer | people | right | marieforcongress | vancouver | sign | women | voting | safe | want | choice | vote | democracy | ll | 8pm | com | thanks | watch | future
# Topic 2:
# https | flip | kent | joe | help | rt | wa03 | congress | choice | november | blue | seat | mgpforcongress | amp | running | working | make | money | need | small | race | white | owner | ad | big | washington | join | district | mother | true
# Topic 3:
# people | day | thank | county | congress | campaign | https | like | democrats | fight | voices | represent | cowlitz | warren | fix | today | letter | wonderful | good | continues | capitol | funded | bring | support | dinner | looks | washington | movement | years | ve
# Topic 4:
# https | tonight | support | honored | thank | endorsement | country | climate | work | republicans | working | today | listen | democracy | debate | joe | herrerabeutler | like | kent | going | make | win | donate | mobilize | families | extremist | wa03 | nu88rk | care | washington
# Topic 5:
# https | kent | joe | longview | flipwa03 | don | thank | defeat | time | great | wa03 | congress | need | voters | washington | working | ballots | day | proud | support | government | meet | dangerous | standing | rzglhgjskm | home | work | 4wujtq | issues | bring
#
# Topic 1:
#  - Joe Kent:
#
# 💰 “Forgot” who’s paying his salary (we still don’t know)
# ❌ Has only a “phantom job”, says his ex-campaign manager
# 👮‍♀️ Wants to defund the FBI, who investigate federal election crimes
#
# Tomorrow @OPBTOL hosts the final #WA03 debate. Joe has a lot of questions to answer.
#  - Joe Kent thinks we should end mail-in voting in Washington State.
#
# Vote-by-mail is safe, secure, and Washingtonians don’t want to go back.​​
#
# Join us this Friday for a voting rights rally in Esther Short Park 🪧 🗳
#
# RSVP Here: https://t.co/EXFsmRHVJ5
#  - The stakes couldn’t be higher in this election. We’re running against a field of anti-choice extremists. Join us calling voters across the district to make sure they turn in their ballot before August 2nd. Register to volunteer here: https://marieforcongress.com/volunteer/
#  - It’s Election Day. I’ve cast my vote and I hope I’ve done everything to earn yours.
#
# As a pro-choice mom who runs an auto shop, I'll be an independent voice for working families like mine.
#
# I need your vote today. Return your ballot by 8pm 🗳️ https://t.co/uV9Ps1wMAl
#  - Help me make this Saturday the biggest yet for our campaign‼️
#
# 10:30 am Canvass Launch at Crown Park in Camas
#
# 1:00 pm Rally at
# @LoowitBrewing
#  with
# @BobFergusonAG
#  &
# @WaTreasurer
#
#
# Let’s knock on some doors🚪& drink some beer! 🍻 RSVP Here: https://mobilize.us/marieforcongress/
#  - Join me this Saturday for our Longview and Vancouver canvass kick-offs! First we’ll rally, next I’ll say a few words, and then we’ll all go knock on doors to tell our neighbors about this important race.
#
# RSVP and learn about other upcoming events here:
# https://mobilize.us/marieforcongress/
#  - Lindsey Graham is trying to pass a national 15 week abortion ban. But that wouldn’t be enough for Joe Kent who wants to criminalize abortion &amp; end it entirely.
#
# We can't let the government control what women do with their bodies. It doesn't represent our values as Washingtonians.
#  - “White Nationalists Dominate Discussion at Joe Kent Town Hall”
#
# This is the future Joe Kent wants for Southwest Washington. It’s the world he’s already living in.
#
# But the rest of us still have a choice. Today we must all say No to Joe Kent.
#
# Return your ballot by 8pm 🗳 https://t.co/1JjLICyW8W
#  - While I knock on doors and talk to voters, Joe Kent is telling lies about the ballot count.
#
# Vote-by-mail is safe and secure. #WA03 voters have known this for years. Kent trusted the results when he barely advanced in the primary. What’s he afraid of now?
# https://t.co/xwOhWm2QU8
#  - It’s clear #SCOTUS respects neither precedent nor women’s basic right to bodily autonomy. It’s more critical than ever that mothers like me fight for our right to determine our future. We must protect our freedoms & stop politicians from taking rights away. Yours could be next.
#  - Kent thinks we need to raise the retirement age for social security since people are living longer.
#
# You know who’s not living longer? People who work in the trades. People like me and my family.
#
# Kent won't be a voice for seniors or working families. We must do better in #WA03
#  - We’ll have volunteers at the Vancouver Farmers Market tomorrow from 9:00-3:00. Come say hi & grab a yard sign! If you’re interested in working at your local farmer’s market reach out to volunteer@marieforcongress.com!
#  - Feel so relieved after getting my 11 month old son his second shot last Saturday. Thanks to the thousands of patriotic families who volunteered in the trials. Vaccines have been critical for decreasing the spread of covid and preventing hospitalizations, your service saved lives
#  - Women across the district are fired up because they know what’s at stake in this election.
#
# There are many ways to be involved with the campaign. Huge thanks to our wonderful team of postcard writers ✍️ for getting the word out one letter at a time! 💌 https://t.co/ceIYU8wKqS
#  - Joe Kent says he's all about “Law &amp; Order” but wants to defund the FBI &amp; local police.
#
# Says he's pro worker, but is anti union.
#
# Says he loves democracy, but won’t accept the 2020 election results.
#
# These mental gymnastics are gold medal worthy. 🥇
#  - Joe Kent wants to dismantle mail-in voting.
#
# Let’s be clear: vote-by-mail is safe and secure. It ensures voters who are rural, disabled, or doing shift work can still vote.
#
# Kent’s attack on voting rights is an attack on democracy.
#
# https://t.co/1xkSWXfce6
#  - JOIN ME THIS SATURDAY 🗓
# At our canvass kickoffs in Longview and Vancouver
#
# Come grab a yard sign 🪧 hear me speak 📢 and knock on some doors! 🚪
#
# RSVP Here: https://mobilize.us/marieforcongress/
#  - Having support from wonderful volunteers across the district means so much to me. You all are making a huge difference in this race! If you would like to be involved, we have many upcoming events.
#
# You can RSVP and learn about other opportunities here: https://t.co/KNX4nQyxvp https://t.co/HhqJ9jmw3V
#  - No matter how much
# @herrerabeutler
#  spends on TV ads telling us she’s a moderate her voting record is clear. She’ll take away your right to marry who you love she will take away your right to contraception and freedom of choice. I am the only candidate who will protect our rights.
#  - Signs are going up, all thanks to some of our wonderful volunteers Ken, Joe, and Tom!
#
# Also, we will be at the Hazel Dell Parade this weekend and would love for you to walk with us! Please reach out via DM or to madeleine@marieforcongress.com if you’d like to join!
#
# Topic 2:
#  - My extremist opponent has released his first TV ad. He wants to:
#
# ❌ Ban abortion everywhere
# ❌ Defund the FBI
# ❌ Abandon Ukraine
# ❌ Arrest Dr. Fauci
#
# I’ve got exactly 4 weeks to show voters what’s at stake in this election. RT &amp; chip in to help me win ⤵️
# https://t.co/RRm9Oksbin
#  - I want to fix things:
#
# ✅ Inflation &amp; our economy
# ✅ Cost of living
# ✅ Career &amp; technical education
#
# Joe Kent wants to break things:
#
# ❌ End vote-by-mail
# ❌ Defund the FBI
# ❌ Ban abortion everywhere
# ❌ Ban all immigration
# ❌ Arrest Fauci for murder
#
# RT to show the choice is clear https://t.co/Djlv2Vmu7G
#  - Thank you,
# @BoldDems
# !
#
# The choice here in #WA03 is clear: MAGA extremist Joe Kent wants to ban immigration for 20 years and puts white nationalists on his payroll.
#
# I’m a pro-choice mom, daughter of an immigrant, and small business owner who will work for all Washington families.
#  - At tonight’s debate, I spoke about:
#
# ✅ Protecting democracy
# ✅ Career and technical education
# ✅ Being an independent voice for SW Washington
#
# Joe Kent called for:
#
# ❌ Arresting Dr. Fauci
# ❌ A national abortion ban
# ❌ Abandoning Ukraine
# ❌ Defunding the FBI
#
# The choice is clear.
#  - My platform is simple, we need to:
#
# - Revitalize Trades Programs
# - Reshore Manufacturing
# - Get Big Money out of Politics
# - Federally Protect Reproductive Freedoms
#
# I’ll work to find real solutions, not align with extreme views that keep Congress from getting sh*t done
#  - Joe Kent is running a spooky TV ad telling lies about me, but here's the truth about Joe Kent:
#
# 1. He denies the results of the 2020 election 🗳
# 2. He plans to privatize Social Security 💵
# 3. He wants to ban all immigration for 20 years to stop "demographic replacement" 🚩
#  - My platform is simple, we need to:
#
# 👷‍♂️ Reshore Manufacturing
# 🛑 Put a stop to corporate price gouging
# 💸 Get Big Money out of Politics
# 🙅‍♀️ Federally Protect Reproductive Freedoms
#
# I’m bringing real solutions to real problems that impact everyday Washingtonians.
#  - I’m not your typical candidate for Congress. I’m a small business owner and a mom who works in the trades and lives on a gravel road.
#
# I fix things for a living, and I’m running to fix what’s broken in our economy.
#
# Thousands of ballots will be cast today. Please RT and vote 🗳 https://t.co/xDRwy517um
#  - There is a strong base of Democrats in our district and as a rural democrat who works in the trades, I am the candidate who can flip this seat. Kent is far too extreme & Jaime has been a no-show when we need her the most. SW WA deserves real representation. Let’s flip #WA03
#  - Hope is the driving force when you’re up against a field of extremist candidates. #WA03 is tired of Jaime Herrera Beutler and Joe Kent is far too extreme for our district. I know we can flip this seat blue! Thank you,
# @OPB
# , for telling this story.
#  - Just learned
# @AP
#  has called the race for us! We have won this primary despite being outspent over 10 to 1. #WA03 is looking for change and I will deliver. I will fight to make sure that working families, small businesses, and mothers have the representation they deserve.
#  - (2/2) "Stradley, a 79-year-old retired truck driver who considers himself a political independent, said he’d voted for Herrera Beutler in the primary. But he’ll be backing Gluesenkamp Perez this fall"
#
# This is about real solutions for working Washingtonians – not party. #FlipWA03
#  - Candidates agree to rules before debates, but Joe Kent thinks keeping your word doesn't matter. Thanks @LWVClarkCounty for holding him accountable.
#
# I don’t need to edit videos to make Kent sound extreme. He does that all on his own. Watch the full debate:
# https://t.co/CeKbkPxW5h https://t.co/u5PrmG8vcH
#  - This ad was made possible by grassroots donors like you. We’ve got just 5 weeks to beat Joe Kent, and I need your help now.
#
# Please chip in what you can today to keep this ad running and flip #WA03 blue.
# https://t.co/RRm9Oksbin
#  - I don’t want Washington to be a place where AC in the summer is as important as heat in the winter. We need to fight climate change, not support big oil companies. That’s why I’m not taking a dime of corporate PAC money – We need legislators who work for us!
#  - I’m running to be an independent voice who will get things done. Top of my list:
#
# ☑️Protect reproductive rights
# ☑️Fight for working families in #WA03
# ☑️Keep big money out of politics
#
# There are 50 days until the election. Help me share my message!
#  - I'm running in one of the most crucial races in the country.
#
# My opponent “stands with” Bannon, thinks we should abolish the Department of Education and enact a nation-wide abortion ban. Please help me spread the word about this important race!
#  - I’m Marie Gluesenkamp Perez, the Democrat who beat Joe Kent in the primary and will beat him again in November.
#
# With your help we’ll flip this seat blue, protect abortion rights, and save our democracy.
#
# Join our campaign now ⤵️
#  - The first official #WA03 debate is next Tuesday at 6:00.
#
# I look forward to the opportunity to put on display the stark differences between our views and ensure our district has an opportunity to make an informed choice this November!
#
# RSVP Here: https://mobilize.us/s/HY8P4z
#  - If we haven’t met yet, I’m Marie Gluesenkamp Perez 👋
#
# The rural Democrat, small business owner and pro-choice mother who beat Joe Kent in the primary and will beat him again in November. https://t.co/WTI2GqJQnL
#
# Topic 3:
#  - I’m running to unite people from across the aisle to stop inflation, create family wage jobs &amp; bring federal $$ home for vital infrastructure.
#
# Joe Kent has focused his campaign on divisive culture wars to distract from his lack of real solutions for the people of #WA03.
#  - I had a great time at the
# @ClarkCoDemParty
#  Ogden Dinner this weekend and was honored to speak about the importance of flipping #WA03!! And with our endorsement from champion of democracy
# @BobFergusonAG
# , we’re building a strong team to bring Washingtonians’ voices to Congress 💪
#  - Organizing is a fundamental right protected by the First Amendment.
#
# People need to be able to represent their interests to be treated fairly and earn a living wage. In Congress, I’ll stand up for workers and support meaningful legislation like the #PROAct.
#  - I built my own home because getting a loan in this economy is hard.
#
# I bring my son to the shop with me because it’s impossible to find affordable, local childcare.
#
# I want to fix the struggles of working families because I face them too.
#  - As a reminder, I own an auto repair and machine shop with my husband (it’s called DEAN’S CAR CARE btw).
#
# Dean and I are working parents who have difficulty finding child care options and had to build our own home because it’s so hard to get a loan.
#  - Joe Kent’s QAnon rants are desperate, weird, and do nothing to improve the lives of people in our district.
#
# Anyone who’s tired of this shit is welcome to join my campaign instead. I’m running because Congress could use someone who actually knows how to fix things. https://t.co/hrMAnVXytH
#  - I’m honored to receive the endorsement of Rep. Sharon Wylie (49th LD). Sharon has been a leader in the fight for economic, healthcare, and energy reform. I’m fighting hard to join her in this critical work in Congress for WA-03!
#  - Affordable childcare is impossible to find. So my husband and I take our son to our auto shop with us most days.
#
# In Congress, I’ll fight for child tax credits so parents can make the choices that are right for their family.
#  - I always love an excuse to come out to the Washington Coast. Thanks to everyone who joined me at the parade and meet & greet in South Bend.
#
# I’m looking forward to Labor Day picnics in Kalama & Chehalis today!
#  - Today is a day to honor the legacy of the United States and push ourselves to live up to its potential. Had a great day in Longview, thank you to the Cowlitz County Democrats for hosting me. You represent the America I am proud to live in and the one I will fight for in Congress
#  - What a powerful message today from
# @Shut_downAmazon
#  in the Senate. I stand with workers’ rights to unionize for fairer pay and better conditions— we need legislation like the PRO Act to hold corporations accountable for retaliating against union organizers.
#  - Thank you
# @HerreraBeutler
#  for serving Southwest Washington. We may not always see eye to eye, but we both value democracy, the rule of law, and free, fair, open elections. I know most voters in our district share those values too.
#  - I am about civility and building community,” McDonald said. “I don’t see that in him. When you legislate, you have to come to the table and have a conversation.”
#
# Thank you for supporting this campaign, Kathy. County over party. #WA03
#  - I spent my day learning more about flood, fish passage, and sediment issues on the Toutle River with Cowlitz County Commissioner Dennis Weber. He’s a Republican and I’m not, but that doesn’t mean we can’t work together to fix things. We need leaders who unite us, not divide us. https://t.co/epa3Ds1ItA
#  - In congress, I will take on politicians who try to get between a woman and her doctor and fight to protect abortion rights that the Supreme Court put in jeopardy. It’s more important than ever that mothers like me stand up for our rights.
#  - Looking forward to dinner with the Skamania County Democrats tonight.
#
# This is what a truly people-powered movement looks like!
#  - Abortion is not a “Democrat issue.” It affects everyone. In rural counties, people like myself have limited access to essential services. I get my water from a well, and I get my internet from a radio tower – but reproductive health care is even more scarce. 1/4
#  - I'll be making three stops to hear your needs and share how my platform can truly address them.
#
# Connect with me across #WA03 this weekend, it's gonna be a good one.
#  - Many thanks to our volunteers and especially
# @bhennrich
#  and his wonderful family for walking with us in the Hazel Dell Parade yesterday!
#  - Joe Kent says the attack on #January6th "reeks of an intelligence operation" done by the police. Even today he continues defending the violent mob that ransacked the Capitol. https://t.co/AyP0ipQEqW
#
# Topic 4:
#  - I'd love to see you tonight at our virtual reception! Get your tickets and come hear how I plan to defeat the extremists in our race for WA-03 and bring real leadership to our district. Online at: https://secure.actblue.com/donate/mgp3-30-2022 #FlipWA03
#  - Proud to receive the OFFICIAL endorsement of the Washington State Labor Council
# @WAAFLCIO
# ! Now more than ever, its critical that our country has leadership that knows what its like to put in a hard days work and respects the trades that make our country thrive.
#  - Last year, I paid more in taxes than Jeff Bezos, the second-richest person in the country – you read that right. This system doesn’t work for everyday folks. Stand with me to demand a fair tax code that forces the ultra-wealthy to pay their fair share: https://secure.ngpvan.com/rpEHsxFarEiS39oH9kgHlQ2
#  - Joe Kent is pro-partisan gridlock. He thinks the way to get what you want in Congress is to hold up the process.
#
# This doesn’t help voters get food on the table and gas in the tank.
#
# #WA03 deserves a Representative who’s willing to work across the aisle to get things done.
#  - Honored to receive the endorsement of
# @larsenrick
# ! I look forward to joining him in Congress to fight for families across Washington state, advancing our shared values from climate action to affordable health care, economic resiliency and more.
#  - Today we honor those who have lost their lives to preserve our freedoms and protect us all. I am humbled by their sacrifice and grateful for their example. Let us never forget them and work to create a united and just America for all with their legacy in mind 🇺🇸
#  - From Pacific County, to my home in Skamania and everywhere in between, voters have stood up for women, working families, and our democracy.
#
# Today is when we bring our hard work home. Get your ballots in before 8 pm tonight so we can win this thing! https://t.co/Z3T6Uc15hf
#  - Representative Kilmer is a tireless champion for Washington families working to create jobs, protect our environment, and support bipartisan legislation.
# @DerekKilmer
# , thank you for your endorsement, I’m looking forward to serving with you in Congress!
#  - Today,
# @HerreraBeutler
#  celebrated the end of Roe by voting against a bill to protect our access to contraceptives- one thing we can all agree actually prevents abortion. Jaime is not a moderate and has failed to give #WA03 the representation we deserve.
#  - We haven’t seen late-season snow like this in decades - and especially not at this level! It’s a clear reminder of the weather rollercoaster brought on by climate change, and how it impacts our infrastructure and way of life. I hope you are all staying warm and safe this week!
#  - Btw, I’ve released the last 3 years of my tax returns. I run an auto repair and machine shop with my husband, and I’m proud to work in the trades. https://t.co/xBRcviS8Xl
#  - Our supply chain is stretched to a breaking point. I see the impact at our auto shop every day. The future of good jobs in #WA03 depends on whether we can breathe life back into American-made manufacturing with investments in career &amp; technical education.
# https://t.co/YBfqq8jCUn
#  - Last night’s debate settled it: Joe Kent’s agenda is nothing but dangerous extremism and fear-mongering.
#
# I’m running to support Washington families because we deserve better than clickbait politics.
#
# Listen here:
# https://t.co/27P8MOKmVf
#  - Listen to lifelong Republicans and @HerreraBeutler voters explain why they cannot vote for anti-democracy extremist Joe Kent.
#
# I'm honored to earn their vote. Country over party. https://t.co/Ax4a0XuhaC
#  - Voting is the cornerstone of democracy. Joe Kent and his MAGA friends want to make it harder because it’s the only way they can win.
#
# Get registered. Make a plan. We can’t let extremist views represent #WA03.
#  - I'm committed to taking the actions necessary to confront the climate crisis. My opponent thinks climate change is a hoax invented by the Chinese government to make money. #WA03 needs a Member of Congress, not an extreme conspiracy theorist. Thank you @LCVoters for your support. https://t.co/BvvQu35wKN
#  - Joe Kent lives in a far-right fantasy world. He believes the rioters who attacked the Capital are "political prisoners".
#
# Remember January 6th when you vote. Please watch and share. https://t.co/9BJmIMpKiH
#  - I am honored to have the endorsement of
# @RepDelBene
# ! Representative DelBene is a champion for working families, the environment, health care and is a fellow
# @Reed_College_
#  alumni! So thankful for her congressional work and value her support.
#  - We’re going to flip #WA03 with the support of folks just like you- thanks to everyone who came out tonight. Looking forward to Camas Days Parade tomorrow!
#  - I am outraged by today’s Supreme Court decision to reverse Roe v. Wade.
#
# I, like so many, suffered a miscarriage just two years ago.
# @PPact
#  was one of the only places I could turn to get the care I needed, which in this case was an assisted abortion
#
# Topic 5:
#  - Joe Kent’s obsession with divisive culture wars may get him a lot of attention, but it’s not going to help people in this district. It’s not going to bring jobs home, support workers, or stop inflation.
#
# We need a Member of Congress who knows this district &amp; has real solutions.
#  - As a small business owner, I know how tough it’s been to navigate inflation.
#
# While gas prices soar, oil companies are making record profits. It’s time for Big Oil to pay their fair share. In Congress I’ll work to stop price gouging and bring energy costs down for working people.
#  - More lies from Joe Kent. I'm proud to earn an honest paycheck. I've released the same 3 years of my tax returns: https://t.co/xBRcviS8Xl
#
# Here's the real mystery: who is signing Joe Kent’s paychecks and what is their agenda?
#
# Voters still don’t know, and Joe Kent won’t tell us. https://t.co/4qQOx1hYVy
#  - Southwest Washington deserves a voice in Congress who understands our local issues &amp; will work to solve them.
#
# I’m the only candidate who will work across the aisle to bring the federal dollars we send to D.C. back home. Joe Kent wants to burn bridges. I’m going to build bridges.
#  - (3/3) I’m ready to #FlipWA03 and get to work on the issues that affect our communities most deeply. We’re counting on your grassroots support to help us defeat Joe Kent and bring the voices of working Washingtonians to Congress. Chip in here: ​​
#  - I’m ready to #FlipWA03 and get to work on the issues that affect our communities most deeply. We’re counting on your grassroots support to help us defeat Joe Kent and bring the voices of working Washingtonians to Congress. Chip in here: ​​
#  - Glad to earn The Columbian's endorsement. They hit the nail on the head: "Perez has focused on issues that matter here while Kent has spent time trying to build his national profile. One candidate will work for SW WA; the other will seek celebrity status.”
# https://t.co/PtFGy7Bo6e
#  - #WA03 families like mine are getting hit hard by rising costs. Inflation is a global issue, not a partisan issue – but Joe Kent would rather cast blame than propose a real solution.
#
# We must revitalize American manufacturing and re-invest in career and technical education.
#  - As a proud ally, I want to thank everyone who listened to and spoke with me at Pride in the Park on Saturday. It’s time to fight for all our rights and ensure the LGBTQ community gets the representation it has been missing for the past 12 years! #flipWA03 #MGPforCongress
#  - Let’s be clear: Joe Kent wants to privatize the VA. His “plan” would make veterans pay higher costs for lower quality health care. It’s another extremely bad idea from a guy who offers nothing else.
#
# What we really need is a fully-funded VA dedicated to serving veterans first.
#  - I am proud to have built my own home in Skamania County, but the reality is that we didn’t have a choice. Getting approved for a loan is a nightmare and as a young family it was nearly impossible. In Congress, I’ll fight to bring down the cost of living for Washington families.
#  - Ballots have started arriving in mailboxes! This is crunch time. This race will come down to how many voters we can reach over the next few weeks.
#
# We will defeat Kent and #FlipWA03, but only with your support. Chip in to fund our voter outreach efforts: https://t.co/iQsEmAa5kB
#  - Had such a great weekend! On Sunday my family and I went to Bizi Farms 🚜 and got to connect with Washington Farmers at the Clark-Cowlitz Farm Bureau Picnic!
#
# On Saturday I got to walk in the Skamania County Parade and take home the newest member of our team, Jarry! 🦃
#  - So many of you also expressed how important it is that we defeat Joe Kent and his dangerous brand of MAGA-extremism, and above all protect our democracy. This really drives home what’s at stake in the #WA03 election.
#  - (2/3) So many of you also expressed how important it is that we defeat Joe Kent and his dangerous brand of MAGA-extremism, and above all protect our democracy. This really drives home what’s at stake in the #WA03 election.
#  - Had a great time talking to voters at the Clark County Fair yesterday. Thanks to everyone who took the time to speak with me about this important race! These are the voices I’m committed to bringing to Congress.
#  - Thank you to everyone who came out to our rally this evening.
#
# I was honored to be joined by #WA03 native Lt. Gov Heck &amp; so many wonderful supporters who understand what’s at stake in this election. https://t.co/PHrgNTJeMO
#  - Joe Kent thinks the January 6th attack on the Capital was an "intelligence operation" planned by a shadowy, unnamed cabal. He is disconnected from reality and a threat to our democracy.
#
# Please watch &amp; share to help me defeat him. https://t.co/fvU5t3KHld
#  - Radical right-wing extremist and white nationalist Joe Kent is the #1 priority for #MAGARepublicans in the midterms. Right now, the only thing standing between Kent and Congress is me.
#
# Stop Kent and his dangerous agenda by joining our movement today:
#  - I’ll be in Longview this Thursday for the for the third #WA03 Debate! Tickets will be available on a first-come-first-serve basis at the venue starting at 5:30.
#
# Let us know you’re coming: https://t.co/6BhcXPrYww https://t.co/Ktpmwa15td
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/forrestwilliams/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/forrestwilliams/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0    [pacific, county, home, skamania, everywhere, ...
# 1    [making, calls, online, amp, person, starting,...
# 2    [everyone, pitched, make, campaign, strong, to...
# 3    [comparing, weird, rally, january, dunk, think...
# 4    [want, get, know, stand, watch, video, candida...
# Name: processed_tweets, dtype: object
# 0    [[-0.11318, 0.5062, -0.049727, -0.6019, -0.220...
# 1    [[-0.00065223, -0.12034, 0.46303, 0.26886, -0....
# 2    [[0.083388, 0.78767, 0.13946, 0.087604, 0.2119...
# 3    [[0.14647, -0.396, 0.59402, 0.19365, 0.04788, ...
# 4    [[-0.00010287, 0.61486, 0.10247, 0.8551, -0.82...
# Name: tweet_vectors, dtype: object
# 0    [0.056651592, 0.27764928, 0.09045536, -0.07547...
# 1    [0.042626698, 0.4640896, -0.05916787, -0.24449...
# 2    [-0.15714599, 0.5316516, 0.08266478, -0.285243...
# 3    [0.057770632, 0.15924203, 0.07209626, -0.16738...
# 4    [0.15329082, 0.6445816, -0.040088523, 0.037500...
# Name: average_vector, dtype: object
# (394, 100)
# Top tweets for Component 1:
#  - The voices of ordinary, working people are missing from Congress and things won’t get better until people like us are elected.
#
# There are two more days to get your ballot in. 🗳 Together we can make the system work for working people.
#  - @IAmPoliticsGirl Thank you for your support! 💙
#  - Get ready to see a lot more of this!
#
# This is a huge race and we need volunteers to help us win. Join our campaign ➡️ http://marieforcongress.com/volunteer/
#  - When I look at Congress I don’t see people who represent me or my neighbors.
#
# I’m running to bring the voices of working people back to Washington D.C.
#  - Help a working mother and small business owner get to Congress!
#  - We’re going to flip #WA03 with the support of folks just like you- thanks to everyone who came out tonight. Looking forward to Camas Days Parade tomorrow!
#  - Looking forward to dinner with the Skamania County Democrats tonight.
#
# This is what a truly people-powered movement looks like!
#  - Kent thinks we need to raise the retirement age for social security since people are living longer.
#
# You know who’s not living longer? People who work in the trades. People like me and my family.
#
# Kent won't be a voice for seniors or working families. We must do better in #WA03
#  - In Congress, I’ll fight to make sure everyone has the right to choose what they do with their bodies. An important part of that right is ensuring people have access to the healthcare they need regardless of where they live 4/4
#  - If you want to get to know me and what I stand for, watch this video.
#
# If I’m your candidate after watching, please share and retweet to help more people see.
#
# Most of all, please VOTE and return your ballot by 8pm 🗳 https://t.co/FD3kmhORKq
#  - Election Day is one week away! This is not a race that you want to sit in the back seat and observe. There is far too much at stake.
#
# There is still time to make a difference. Don’t watch the news a week from today and wish you had done more. Sign up now: https://t.co/4ihF9l4yY4
#  - I want to thank
# @bhennrich
#   for his hard work and his deep commitment to democracy. I am humbled and appreciate his willingness to make sure we unite to #FlipWA03. Let's go win this race, it's going to take all of us.
#  - Running for office is one of the most demanding things I’ve ever done.
#
# But every day I get to meet more people from more communities and see the campaign grow. We can flip this seat and make sure the interests of real Washingtonians are represented in Congress.
#  - Thank you
# @HerreraBeutler
#  for being one of only 9 Republicans willing to stand up for our democracy today. Country over party.
#  - When we started this campaign we had less than a 100 followers.
#
# Today, our people powered movement has grown by tens of thousands online. It’s going to take every one of us to get across the finish line.
#
# We can’t stop here. Share our movement to help us keep growing! https://t.co/Kdvcx5Qhi8
#
# --------------------------------------------------
#
# Top tweets for Component 2:
#  - #LlamasforMarie 🦙🦙 https://t.co/VkxD7lnzDJ
#  - https://t.co/G7nazDJybh
#  - https://olvr.votewa.gov
#  - Here’s the transcript:
#
# https://t.co/RzgLHGJsKM https://t.co/DOaYSAtZQo
#  - RSVP for Vancouver: https://mobilize.us/s/Nu88rk
#  - RSVP for Vancouver: https://mobilize.us/s/Nu88rk
#  - Be on the lookout 🏍 https://t.co/vGDWDAfNfd
#  - RSVP for Longview: https://mobilize.us/s/4wUjtq
#  - RSVP for Longview: https://mobilize.us/s/4wUjtq
#  - Vancouver Rally: https://mobilize.us/s/0fj4fY
#  - You can find out about upcoming volunteer opportunities here: https://t.co/p4SULgTn7S https://t.co/pRMC8uJW2G
#  - Camas Canvass: https://mobilize.us/s/g7FqL1
#  - Sign up for a canvassing shift here: https://t.co/4ihF9llC04
#  - @DeborahJ242017 You can watch the recording here: https://t.co/l9RTwb60vP
#  - @CJYART1 Yes, the recorded livestream is available here: https://t.co/l9RTwb60vP
#
# --------------------------------------------------
#
# Top tweets for Component 3:
#  - Here’s the link to watch online:
#  - RT @IAmPoliticsGirl: @MGPforCongress If you’d like to know more about @MGPforCongress I had a wonderful conversation with her about represe…
#  - First #WA03 Debate is TONIGHT at 6:00 pm. You can watch the event livestream here 💻 https://t.co/VpSmEfylcO
#  - To those of you who think we can’t flip this seat…👇
# Quote Tweet
# ESPN
# @espn
# ·
#  - Happy Halloween 🎃 Need a last-minute costume idea? https://t.co/NrAWytHq75
#  - We’re going to flip #WA03 with the support of folks just like you- thanks to everyone who came out tonight. Looking forward to Camas Days Parade tomorrow!
#  - @CJYART1 Yes, the recorded livestream is available here: https://t.co/l9RTwb60vP
#  - Glad everyone enjoyed our new TV ad — Uma and I had fun moving the slash! https://t.co/4xy3uLeOH3 https://t.co/W57huIiCb7
#  - We’re in La Center, come pick up yard signs and say hi!
#  - It really did feel like a YouTube rant. https://t.co/8GfHsX9ZvZ
#  - So much fun in Pacific County today. Thank you to everyone who came out in Ilwaco & Raymond!
#  - RT @thecolumbian: “If you piss everybody in the world off, like Joe will do, you can’t move the ball forward,” said Kathy McDonald, who res…
#  - @DeborahJ242017 You can watch the recording here: https://t.co/l9RTwb60vP
#  - RT @DianaCCastaneda: La opción es clara #WA03 @MGPforCongress quiere mejorar:
# ➡️ Nuestra economía
# ➡️ Inflación y costo de vida
# ➡️ Educaci…
#  - Signs are going up, all thanks to some of our wonderful volunteers Ken, Joe, and Tom!
#
# Also, we will be at the Hazel Dell Parade this weekend and would love for you to walk with us! Please reach out via DM or to madeleine@marieforcongress.com if you’d like to join!
#
# --------------------------------------------------
#
# Top tweets for Component 4:
#  - If you’re pro-worker, you’re pro-union.
#
# It’s that simple.
#  - RT @DianaCCastaneda: La opción es clara #WA03 @MGPforCongress quiere mejorar:
# ➡️ Nuestra economía
# ➡️ Inflación y costo de vida
# ➡️ Educaci…
#  - #LlamasforMarie 🦙🦙 https://t.co/VkxD7lnzDJ
#  - https://t.co/G7nazDJybh
#  - https://olvr.votewa.gov
#  - Here’s the link to watch online:
#  - It really did feel like a YouTube rant. https://t.co/8GfHsX9ZvZ
#  - Congress could use someone who actually knows how to fix things. Please watch and share our new TV ad if you agree. https://t.co/lA0gfdwcub
#  - RT @IAmPoliticsGirl: @MGPforCongress If you’d like to know more about @MGPforCongress I had a wonderful conversation with her about represe…
#  - My business definitely exists, not that anyone needed to ask.
# https://t.co/EFCL6VZSq7
#  - Here’s the transcript:
#
# https://t.co/RzgLHGJsKM https://t.co/DOaYSAtZQo
#  - Mr. “Law &amp; order” here wants to defund the FBI https://t.co/zGURsVM55B https://t.co/diz6LBVF6q
#  - To those of you who think we can’t flip this seat…👇
# Quote Tweet
# ESPN
# @espn
# ·
#  - When the future speaks, listen.
#  - Chip in to elect someone who will keep big money out of politics:
#
# --------------------------------------------------
#
# Top tweets for Component 5:
#  - RT @DianaCCastaneda: La opción es clara #WA03 @MGPforCongress quiere mejorar:
# ➡️ Nuestra economía
# ➡️ Inflación y costo de vida
# ➡️ Educaci…
#  - Here’s the link to watch online:
#  - RT @LetAmericaVote: In #WA03, we're endorsing #NoCorporatePAC Democratic candidate @MGPforCongress. https://t.co/KeonZ1X6BZ
#  - RT @thecolumbian: Republican David Nierenberg, a major donor to Democratic candidate @MGPforCongress’ campaign, sent letters to the FEC and…
#  - To those of you who think we can’t flip this seat…👇
# Quote Tweet
# ESPN
# @espn
# ·
#  - Being anti-union is a red flag 🚩
#  - It’s official: Joe Kent joins his idols Marjorie Taylor Greene and Matt Gaetz in the “defund the FBI” club. Congrats are not in order.
#  - First #WA03 Debate is TONIGHT at 6:00 pm. You can watch the event livestream here 💻 https://t.co/VpSmEfylcO
#  - New Poll Makes Clear that now with united Democratic field, race in November will be between me and White Nationalist, anti-choice Joe Kent.  We can, and must, win.
#  - RT @thedailybeast: As Trump-backed congressional candidate Joe Kent tells it, he made $122,110.36 last year as a “project manager” for a te…
#  - Joe Kent will vote for a national ban on abortion and the GOP has made clear that this is a top priority if they have the majority in November.
#
# Electing pro-choice candidates has never been more important. Join me in this fight!
#  - RT @PPAAWest: Marie Gluesenkamp Perez is fighting for our rights in WA's 3rd! "'It doesn’t matter what a woman’s political party is,' she s…
#  - I’m Marie Gluesenkamp Perez, the Democrat who beat Joe Kent in the primary and will beat him again in November.
#
# With your help we’ll flip this seat blue, protect abortion rights, and save our democracy.
#
# Join our campaign now ⤵️
#  - The future of democracy is on the line. Tune into
# @OPBTOL
#  on
# @OPB
#  at 12:00 or 8:00 tomorrow for a debate between Joe Kent and me.
#  - Can’t win this fight alone and tonight we are honored to have the unanimous vote for endorsement from the 18th LD Dems!
#
# --------------------------------------------------
#
# Top tweets for Component 6:
#  - @IAmPoliticsGirl Thank you for your support! 💙
#  - If you’re pro-worker, you’re pro-union.
#
# It’s that simple.
#  - To support my campaign on day one - join our grassroots movement at:
#  - I am honored to have the endorsement of
# @RepDelBene
# ! Representative DelBene is a champion for working families, the environment, health care and is a fellow
# @Reed_College_
#  alumni! So thankful for her congressional work and value her support.
#  - Help us use this momentum to spread my positive, pro-choice message and expand our lead:
#  - Americans who love freedom overwhelmingly support marriage equality. This should not be up for debate in 2022.
#
# I stand with the LGBTQ community & support the Respect for Marriage Act 🏳️‍🌈
#  - Representative Kilmer is a tireless champion for Washington families working to create jobs, protect our environment, and support bipartisan legislation.
# @DerekKilmer
# , thank you for your endorsement, I’m looking forward to serving with you in Congress!
#  - RT @DianaCCastaneda: La opción es clara #WA03 @MGPforCongress quiere mejorar:
# ➡️ Nuestra economía
# ➡️ Inflación y costo de vida
# ➡️ Educaci…
#  - I love our farmers market volunteers! 🫶🫶 https://t.co/WDuzUVDu5K
#  - Keep our campaign well funded:
#  - Make sure you’re connected to the campaign through the volunteer page on my website if you want to hear about future opportunities!
#  - Most importantly, 97% of donations came from grassroots donors and 83% of those donations are from my fellow Washingtonians.
#
# It’s clear our campaign is for working people, not corporate MAGA interests. Give your support here: https://secure.actblue.com/donate/mgp?refcode=website&amount=25
#  - Here’s the link to watch online:
#  - Yesterday, I was excited to join the ribbon-cutting ceremony for the Underwood Conservation District’s Farm Tool Library! I’m proud to work with my neighbors to preserve our natural resources and learn sustainable gardening practices. Local community action is so important.
#  - Proud to stand in solidarity with Weyerhaeuser workers on strike. https://t.co/zQHpPgrI13
#
# --------------------------------------------------
#
# Top tweets for Component 7:
#  - RT @DianaCCastaneda: La opción es clara #WA03 @MGPforCongress quiere mejorar:
# ➡️ Nuestra economía
# ➡️ Inflación y costo de vida
# ➡️ Educaci…
#  - Being anti-union is a red flag 🚩
#  - Vancouver Rally: https://mobilize.us/s/0fj4fY
#  - If you’re pro-worker, you’re pro-union.
#
# It’s that simple.
#  - As a small business owner, I know how tough it’s been to navigate inflation.
#
# While gas prices soar, oil companies are making record profits. It’s time for Big Oil to pay their fair share. In Congress I’ll work to stop price gouging and bring energy costs down for working people.
#  - I am so tired of hearing the #InfantFormula shortage is a woman’s issue…. Four major companies control 90 percent of the infant formula supply.
#  - Purr-fect day to paint your barn 🐱 https://t.co/UYjWIVgYgw
#  - I love our farmers market volunteers! 🫶🫶 https://t.co/WDuzUVDu5K
#  - Rural downtowns are the backbones of rural communities. I’m proud of the work I did to support small businesses as Executive Director of the Stevenson Downtown Association.
#
# You can trust I will show up for this district because I have a record of showing up for my community. https://t.co/9VhJUK9HTH
#  - I built my own home because getting a loan in this economy is hard.
#
# I bring my son to the shop with me because it’s impossible to find affordable, local childcare.
#
# I want to fix the struggles of working families because I face them too.
#  - I’m running to unite people from across the aisle to stop inflation, create family wage jobs &amp; bring federal $$ home for vital infrastructure.
#
# Joe Kent has focused his campaign on divisive culture wars to distract from his lack of real solutions for the people of #WA03.
#  - Camas was a blast! See you all at Loowit Brewing in Vancouver at 1:00.
#  - I don’t want Washington to be a place where AC in the summer is as important as heat in the winter. We need to fight climate change, not support big oil companies. That’s why I’m not taking a dime of corporate PAC money – We need legislators who work for us!
#  - We’ll have volunteers at the Vancouver Farmers Market tomorrow from 9:00-3:00. Come say hi & grab a yard sign! If you’re interested in working at your local farmer’s market reach out to volunteer@marieforcongress.com!
#  - Ask any economist, this kind of market consolidation is dangerous for consumers everywhere, it just happens that these “consumers” are our most vulnerable children.
#
# --------------------------------------------------
# 0    [pacific, county, home, skamania, everywhere, ...
# 1    [making, calls, online, amp, person, starting,...
# 2    [everyone, pitched, make, campaign, strong, to...
# 3    [comparing, weird, rally, january, dunk, think...
# 4    [want, get, know, stand, watch, video, candida...
# Name: processed_tweets, dtype: object
#                                                 text  \
# 0  From Pacific County, to my home in Skamania an...
# 1  We’ll be making calls online &amp; in person s...
# 2  For everyone who has pitched in to make our ca...
# 3  Comparing your weird rally to January 6th is n...
# 4  If you want to get to know me and what I stand...
#
#                               tweet_text_with_breaks
# 0  From Pacific County, to my home in Skamania an...
# 1  We’ll be making calls online &amp; in person <...
# 2  For everyone who has pitched in to make our <b...
# 3  Comparing your weird rally to January 6th is n...
# 4  If you want to get to know me and what I stand...
# 0    [[-0.11318, 0.5062, -0.049727, -0.6019, -0.220...
# 1    [[-0.00065223, -0.12034, 0.46303, 0.26886, -0....
# 2    [[0.083388, 0.78767, 0.13946, 0.087604, 0.2119...
# 3    [[0.14647, -0.396, 0.59402, 0.19365, 0.04788, ...
# 4    [[-0.00010287, 0.61486, 0.10247, 0.8551, -0.82...
# Name: tweet_vectors, dtype: object
# 0    [0.056651592, 0.27764928, 0.09045536, -0.07547...
# 1    [0.042626698, 0.4640896, -0.05916787, -0.24449...
# 2    [-0.15714599, 0.5316516, 0.08266478, -0.285243...
# 3    [0.057770632, 0.15924203, 0.07209626, -0.16738...
# 4    [0.15329082, 0.6445816, -0.040088523, 0.037500...
# Name: average_vector, dtype: object
# (394, 100)
# (394, 7)
# (7, 100)
# Topic 1:
#
#  - We’re going to flip #WA03 with the support of folks just like you- thanks to everyone who came out tonight. Looking forward to Camas Days Parade tomorrow!
#  - The voices of ordinary, working people are missing from Congress and things won’t get better until people like us are elected.
#
# There are two more days to get your ballot in. 🗳 Together we can make the system work for working people.
#  - Looking forward to dinner with the Skamania County Democrats tonight.
#
# This is what a truly people-powered movement looks like!
#  - So much fun in Pacific County today. Thank you to everyone who came out in Ilwaco & Raymond!
#  - Election Day is one week away! This is not a race that you want to sit in the back seat and observe. There is far too much at stake.
#
# There is still time to make a difference. Don’t watch the news a week from today and wish you had done more. Sign up now: https://t.co/4ihF9l4yY4
#  - Great turn out at the Camas Days Parade. Thanks to everyone who walked with us & talked to me today!
#  - Running in one of the most competitive races in the country with a 1 year old isn’t easy – but we make it work. Thank goodness for grandparents and movie magic!
#  - First snow of the year out here in Skamania County! Be safe but don’t let the weather stop you from getting your ballot in by Tuesday at 8pm ☃️🗳 https://t.co/yOMETHNZet
#  - Kent thinks we need to raise the retirement age for social security since people are living longer.
#
# You know who’s not living longer? People who work in the trades. People like me and my family.
#
# Kent won't be a voice for seniors or working families. We must do better in #WA03
#  - Help a working mother and small business owner get to Congress!
#  - Thank you, Vancouver. This is what a winning campaign looks like! Let’s go knock all the doors 🚪
#  - Thanks to everyone who spoke with me at the Juneteenth Festival and to those of you who came to have a beer with me at Hidden House. I’m looking forward to more days like these!
#  - From Pacific County, to my home in Skamania and everywhere in between, voters have stood up for women, working families, and our democracy.
#
# Today is when we bring our hard work home. Get your ballots in before 8 pm tonight so we can win this thing! https://t.co/Z3T6Uc15hf
#  - When I look at Congress I don’t see people who represent me or my neighbors.
#
# I’m running to bring the voices of working people back to Washington D.C.
#  - When we started this campaign we had less than a 100 followers.
#
# Today, our people powered movement has grown by tens of thousands online. It’s going to take every one of us to get across the finish line.
#
# We can’t stop here. Share our movement to help us keep growing! https://t.co/Kdvcx5Qhi8
#  - Get ready to see a lot more of this!
#
# This is a huge race and we need volunteers to help us win. Join our campaign ➡️ http://marieforcongress.com/volunteer/
#  - RT @IAmPoliticsGirl: @MGPforCongress If you’d like to know more about @MGPforCongress I had a wonderful conversation with her about represe…
#  - Congress could use someone who actually knows how to fix things. Please watch and share our new TV ad if you agree. https://t.co/lA0gfdwcub
#  - This is exactly why I'm not taking any money from big corporate PACs! We've got to get dark money out of politics. Join me.
#  - @StateVoter The two ads I have posted here are both airing right now.
#  - We need all hands on deck in these next couple weeks. There are canvassing shifts available every day until Election Day.
#
# Go to https://t.co/4ihF9l4yY4 and sign up for 2 shifts right now!
#
# Thank you, thank you, thank you. https://t.co/KjmQIoFMJM
#  - Help a small business owner who works in the trades get to congress:
#  - Then, I told
# @POTUS
# ...
# , and
# @VenkatforPA
# . Folks are ready to defend our freedom and elect Democrats up and down the ballot this year. Let's win this! #PA17
#  - Jeremy Shaffer and these extremists who tried to overthrow our government are a threat to our freedom. I won't give them an inch. #PA17 #PA17Debate
#  - If you want stuck with the bill for billionaire/corp tax cuts & an abortion ban, check out my right-wing opponent. If you want to fight the greedy corporations gouging us & to bring back our supply chains and jobs, I'm your #PA17 candidate.
#  - Let me be clear - I totally support funding for local police departments! I know what it’s like to wear a uniform and carry a gun to keep us safe and am proud to be backed by unions for cops, firefighters, and prosecutors. #PA17Debate
#  - I was willing to risk my life for our rights, so you know I'll fight to protect reproductive freedom.
#
# My opponent? He'll try to put an abortion ban in the Constitution and wants to force rape and incest victims (even kids) to give birth.
#  - Whether it's in the face of an anti-worker Supreme Court, union busters, or anti-union politicians, I'll always have organized labor's back in a fight. ✊
# @Teamsters
#  - My extremist right-wing opponent believes in a nationwide ban on abortion and is on the record wanting rape & incest victims to be forced to give birth. He's dangerous, out of touch, and a threat to freedom. [1/2]
#  - We should be holding these executives accountable—we definitely don't need them in Congress. #PA17
#  - My right-wing opponent wants a constitutional amendment to ban abortion nationwide. The radical right agenda to treat women like it's the Stone Age is on full display in #PA17, and I'm not going to let the jagoffs win.
#  - #HereWeGo
#  - Harry Truman's work isn't done.
#
# When I get to Washington, I'll protect Medicare and Medicaid from Republican cuts and fight for decent healthcare for every American. #GiveEmHell
#  - These insane Republican threats to Social Security and Medicare would send millions of retirees into poverty. I'll fight them tooth and nail when I'm your #PA17 Congressman.
#  - No need to catch my opponent on a hot mic, his extremist views are out there for all to see. He supports putting an abortion ban in the Constitution, and even opposes exceptions for victims of rape and incest. Way too extreme for western PA.
#  - I'm Chris Deluzio, and I'm about to hold one of the most competitive congressional seats in the country. I'm a veteran, voting rights attorney, and someone who fought to form a union, and I know what is at stake in this election. RT to help us grow our movement & keep #PA17 blue.
#  - My opponent 🤝 Hurting #PA17 seniors
#
# If elected, Shaffer will join other radical Republicans to put Social Security on the chopping block and undermine seniors' health care by cutting Medicare.
#
# I won't let that stand. Our seniors deserve better.
#  - Jeremy Shaffer - western PA is still waiting for an answer to this question. Do you or don’t you support Dr. Oz for Senate and Doug Mastriano for Governor? #PA17Debate
#  - I will defend Social Security and Medicare from the kind of heartless cuts favored by Ron Johnson, Doug Mastriano, and my right-wing opponent in #PA17.
#  - When you send me to Congress, I'll be fighting to make em pay their damn taxes, to bring back our factories, and to give #PA17 workers a fair shot. [2/2]
#  - Let's win this!✊
#  - Great crowd at today’s @bcdemparty
#  golf outing. Beaver County is fired up to elect Democrats up and down the ballot!
#  - From rallying with voters in Verona to meeting with members of the
# @TCCPittsburgh
#  to launching another canvas, #TeamDeluzio is crisscrossing #PA17 to get out the vote!
#  - 💯 @JohnFetterman
#  — let’s get to work!
#  - The weapons of war that my friends and I carried in Iraq should not be allowed in our schools, our churches, or in our streets! Period. #PA17Debate
#  - We need a member of Congress in #PA17 with foreign policy experience to stand up to Beijing.
#
# I'm the only candidate in this race who's led Americans abroad in uniform, who's seen the threat from China, and who has the experience to do the job in DC.
#  - I'm no social media influencer, but I can tell ya corporate consolidation has been hurting all of us in western PA. We need stronger antitrust laws and a government with the guts to enforce them against these corporate giants.
#  - Tomorrow, freedom is on the ballot in #PA17. I'm in this race to protect our rights to vote, to have a union, to make your own pregnancy and health care decisions, and so much more. 🇺🇸
#  - If you want an extremist like my opponent who thinks vicitms of rape or incest (even kids) should be forced to give birth, then I am not your candidate. I'll be fighting in Washington to protect our freedom and girls' and women's rights to decide what's best for them.
#  - The eyes of the country are on #PA17—and we're building the coalition to win.
#
# I don't care if you're a Democrat, an independent, or a Republican, I know you're tired of huge corporations ripping you off. [1/2]
#  - I fought alongside @steelworkers
#  for a union for Pitt workers, and I'll fight in Congress every day for a better deal for all #PA17 workers.
#
# If you can manage it, please consider supporting our campaign as we close out the month.
#
# https://secure.actblue.com/donate/chris-d
#  - This veteran can’t wait to replace Pat Toomey with @JohnFetterman
# . John understands the sacred duty this country has to care for those who wore the uniform. Let’s get John to the Senate!
#  - Honored to be endorsed by
# @NARAL
# . You'll always know where I stand on protecting your freedom to choose. And I'm going to fight hard to protect you from extremists like Doug Mastriano and my opponent and their plans to attack your rights.
#  - I pledged an oath to defend our democracy.
#
# My opponent has bent the knee to the man who is attacking it.
#
# That’s the difference in this campaign. #PA17
#  - Our listening session in Penn Hills was a great time to hear from voters about what they expect from their next #PA17 Congressman. Delivering for western PA & standing up for our democracy against the insurrectionists supporting my corporate executive opponent were top of mind.
#  - Hey
# @JeremyShafferPA
# , stop undercutting American workers with your foreign-made crap tee shirts.
#
# Sincerely, the union-endorsed candidate with shirts made by AMERICAN UNION WORKERS.
#  - Honored to be endorsed by
# @SSWorks
# , and have the support of Jon “Bowzer” Bauman.
#
# I’ll always fight to protect Social Security and Medicare from right wing attacks on seniors.
#  - 🧵Today we celebrate the 57th anniversary of Medicare + Medicaid. LBJ signed the bill. But because Harry Truman (love him!) fought so hard for healthcare as President, Johnson not only invited him to the ceremony, he held the signing at the Truman Library in Independence, MO.
#  - Unlike the anti-abortion extremist I'm running against, you won't see me running dishonest ads about my record, lying to #PA17 voters. [2/2]
#  - I have young daughters. I don’t want Doug Mastriano & Jeremy Shaffer to ever have a say in their reproductive or healthcare decisions. They are extremists who support national abortion bans & are threatening to put women and doctors in prison.
#  - Political leaders shouldn’t make decisions about anyone’s pregnancy.
#
# Women should. Period.
#  - I believe every person deserves to make their own decisions when it comes to their healthcare and planning a family. My opponent wants government to control your body by banning abortion, even for victims of rape and incest.
#  - I was honored to join
# @BarackObama
# ,
# @JohnFetterman
# ,
# @LindseyForPA
#  and many others to rally today. Folks are fired up and ready to vote for Democrats who will deliver results for the hard-working men and women here in Western PA! #PA17
#  - I'm running to take on those corporations and their corrupt politicians, to build solid union jobs, and to fight to make sh*t here again.
#
# Let's get to work.
#  - I will fight in Congress for every American's right to form and join a union, starting with the PRO Act ✊
#  - We had a great crowd tonight in Mt. Lebanon. One thing I hear across #PA17 is fear about the future of our democracy. I’ve protected it in uniform, and I’m ready to fight for it in Congress — and unlike my opponent, you’ll see no insurrectionists endorsing my campaign.
#  - Corporate greed is squeezing the hardworking families of #PA17. I will stand up for western PA and fight the huge corporations gouging us. My right-wing opponent would give them a tax cut.
#  - I've pledged to join the For Country Caucus, a group of veterans from both parties in Congress, who are committed to working in a bipartisan fashion. We know what it means to put this country first, above party, & I'll always work across the aisle to deliver for western PA. #PA17
#  - Here in Western PA, you step up for your community when it’s in crisis. It’s why I joined the Navy after 9/11 and served in Iraq. It’s why I led election security efforts at Pitt. And it’s why I’m stepping up again now - to fight for our Western PA values. #PA17
#  - I'd have voted for this bill. It will make us more competitive with China in the critical semiconductor industry and crank up production here at home. Anybody surprised that 89% of House Republicans voted against the bill?
#  - On the eve of Election Day, I proudly joined our next Lieutenant Governor of Pennsylvania
# @AustinDavisPA
#  at our #TeamDeluzio campaign headquarters to phone bank! Less than 24 hours, #PA17! Let's do this!
#  - Proud to stand on the picket line with
# @AlleghenyLabor
# ,
# @Bob_Casey
#  and the
# @PittsburghPG
#  workers from
# @CWAUnion
# ,
# @Teamsters
# , and
# @PGHGuild
# . I'll always have workers' backs in #PA17.
#  - While these workers are on strike, I will continue to refuse to speak with The Post-Gazette. I will, however, speak with The Pittsburgh Union Progress (
# @ThePUPNews
# ) and suggest folks check out their work at
#  - The Supreme Court has undone decades of precedent in Roe to attack reproductive freedom. They’ve been attacking workers’ rights for years and made unlimited corporate money free speech. People have lost confidence and feel powerless. We need reform! #PA17Debate
#  - I stepped up to serve our country in uniform because I believe deeply in what America is and can be. In Congress, I've committeed to joining the For Country Caucus alongside veterans from both parties, driven by that same belief in America. [1/2]
#  - I am so proud of the broad coalition of grassroots support powering this campaign. Together, we are sending a clear message: #PA17 wants someone to fight for working families and union members, not corporations and billionaires.
#  - These right-wing attacks on elections are continuing, all designed to keep fueling the Big Lie. I first swore an oath to the Constitution as a 17-year old, and I'm just as committed today to protecting our democracy. I won't give 'em an inch.
#  - It was a great morning alongside Senator
# @SherrodBrown
# , Senator
# @Bob_Casey
# , and LG
# @JohnFetterman
#  in Beaver County to rally with labor.
#
# This crew is ready to win the fight in November to protect union jobs, make more stuff right here in #PA17, and take on corporate greed.
#  - 🚨🚨🚨 Beaver County has published the list of voters who need to fix their mail-in ballots. If you voted by mail in Beaver County, please check this list! #PA17
#  - Freedom is on the ballot, folks. My right wing opponent is on record opposing abortions in cases of rape and incest, forcing even victimized kids to give birth. This kind of extremism is a danger to our rights, and folks in #PA17 want no part of it.
#  - Gutting Social Security & Medicare, banning abortion, letting Big Pharma rip you off at the pharmacy, & so much more: the MAGA-Shaffer agenda is wrong for #PA17.
#
# --------------------------------------------------
# /opt/homebrew/Caskroom/miniforge/base/envs/WheeleyDope/lib/python3.11/site-packages/sklearn/decomposition/_nmf.py:1710: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
#                                                                                                                                                                                                                                                                  text  \
# 0                                                                                                I am honored and grateful that the people of #PA17 have elected me as their next Congressman to serve Western Pennsylvania in Congress. Read my full statement here:
# 1                                                                                                                                              Polls are now open, #PA17! I’m out here at the polls in Aliquippa greeting folks and making sure they vote blue today!
# 2                                                                                                                                                                           The sun might have went down, but we are still out at the polls here in #PA17! Go vote! 🗳
# 3                                                                                                        I ended the day at the polls at the place where it all began for me, in Thornburg where I grew up, where I learned the values I’ll take to Washington. #PA17
# 4  Western PA made me the man I am today. From stepping up to serve this country in uniform, to fighting for our common good across #PA17, those values always guide me. And when I'm your Congressman, I will always put you, your families, and this country first.
#
#                                                                                                                                                                                                                                                                    tweet_text_with_breaks
# 0                                                                                                        I am honored and grateful that the people of <br>#PA17 have elected me as their next Congressman <br>to serve Western Pennsylvania in Congress. Read <br>my full statement here:
# 1                                                                                                                                                          Polls are now open, #PA17! I’m out here at the <br>polls in Aliquippa greeting folks and making sure <br>they vote blue today!
# 2                                                                                                                                                                                           The sun might have went down, but we are still <br>out at the polls here in #PA17! Go vote! 🗳
# 3                                                                                                                I ended the day at the polls at the place where <br>it all began for me, in Thornburg where I grew <br>up, where I learned the values I’ll take to <br>Washington. #PA17
# 4  Western PA made me the man I am today. From <br>stepping up to serve this country in uniform, to <br>fighting for our common good across #PA17, those <br>values always guide me. And when I'm your <br>Congressman, I will always put you, your <br>families, and this country first.
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="dde40ea0-8718-449a-8452-9d6ffb1716b3">Loading BokehJS ...</span>
#     </div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="aab1943c-e63f-41f3-b6d9-07510ad9d466" data-root-id="p1045" style="display: contents;"></div>

# %% [markdown]
# ## Creating system for finding Cosine-Similar Words to check corpus of each candidtate for counts and Proportions

# %%
# checking out the vectors for a specific word "extreme"
extreme_vector = glove_model['extreme']
extreme_vector
# Out:
# array([ 0.19004  , -0.66059  ,  0.46406  , -0.70893  ,  0.41803  ,
#         0.29933  ,  0.31733  ,  0.15022  ,  0.40266  , -0.077031 ,
#         0.54478  , -0.59373  , -2.2527   , -0.089099 ,  0.26635  ,
#        -0.19689  ,  0.34807  , -0.58462  , -0.029715 ,  0.038826 ,
#         0.23144  ,  0.21264  ,  0.38468  , -0.43757  ,  0.28824  ,
#         0.42492  ,  0.1347   ,  0.45701  , -0.0048209,  0.10396  ,
#        -0.099282 , -0.95452  , -0.026762 ,  0.5851   ,  0.12944  ,
#        -0.19843  , -0.72514  ,  0.26144  , -0.10765  ,  0.043392 ,
#        -0.72849  , -0.78761  , -0.05543  ,  0.27645  ,  0.36755  ,
#         1.0275   , -1.2297   ,  0.39457  , -0.51206  ,  0.13366  ,
#         0.61787  , -0.36706  , -1.0734   , -0.38454  ,  0.72141  ,
#         0.025711 ,  0.43496  ,  0.33806  , -0.48974  , -0.20187  ,
#         0.0030493,  0.56208  , -0.62427  , -0.010596 ,  0.6963   ,
#        -0.11138  ,  1.0141   ,  0.3226   ,  0.29939  , -0.47968  ,
#        -0.48126  , -0.032319 , -1.436    , -0.17955  ,  0.17077  ,
#         0.29732  ,  0.17253  ,  0.14144  ,  0.021402 , -0.74033  ,
#         1.5726   , -0.4029   ,  0.319    ,  0.032445 ,  0.4925   ,
#         0.24142  ,  0.4986   , -0.29     , -0.17947  ,  0.23347  ,
#        -0.2656   ,  0.093643 ,  0.37327  , -0.065988 ,  0.17915  ,
#        -0.019774 , -0.3028   , -0.37028  , -0.25539  , -0.19888  ],
#       dtype=float32)

# %%
# checking top 50 words cosine-similar to "extremist"
extremist_similar_words = glove_model.most_similar('extremist', topn=50)
print(extremist_similar_words)
# Out:
# [('extremists', 0.8193550109863281), ('right-wing', 0.7939763069152832), ('leftist', 0.7213768362998962), ('islamist', 0.715599536895752), ('religious', 0.704314112663269), ('extremism', 0.7023181915283203), ('left-wing', 0.6947838068008423), ('fundamentalist', 0.6925621032714844), ('terrorist', 0.6889837980270386), ('militant', 0.6823937296867371), ('bigots', 0.6720960736274719), ('xenophobic', 0.6672667860984802), ('marxist', 0.6614766120910645), ('evangelical', 0.6529259085655212), ('ideological', 0.6516067981719971), ('jihadi', 0.6500540375709534), ('militia', 0.6498481631278992), ('jihadist', 0.6481633186340332), ('ideology', 0.6451252698898315), ('conservative', 0.6414011120796204), ('zionist', 0.6406401991844177), ('christians', 0.6378111839294434), ('bigot', 0.6370280385017395), ('rightwing', 0.6354671716690063), ('atheist', 0.6338337659835815), ('fundamentalists', 0.6309073567390442), ('fascist', 0.6307145357131958), ('terrorists', 0.6282757520675659), ('communist', 0.6255199313163757), ('feminist', 0.6243675351142883), ('islamic', 0.620008111000061), ('socialist', 0.6174951791763306), ('political', 0.6172088384628296), ('jihadists', 0.6162304282188416), ('populist', 0.614788830280304), ('pro-life', 0.6138304471969604), ('evangelicals', 0.6128724813461304), ('secular', 0.6118825078010559), ('pro-choice', 0.6115636229515076), ('reactionary', 0.6096038818359375), ('elitist', 0.608900249004364), ('anti-christian', 0.6085803508758545), ('fascists', 0.6075684428215027), ('nationalist', 0.6064186096191406), ('atheists', 0.6022339463233948), ('islamists', 0.6022196412086487), ('muslims', 0.6011817455291748), ('homophobic', 0.6008630394935608), ('leftists', 0.5990918874740601), ('bigoted', 0.5974420309066772)]

# %%
# Create a function for generating similar words that includes the original word and spits out two lists for arranging

def generate_similar_words(word):
    similar_words = glove_model.most_similar(word, topn=50)
    
    # make sure the primary word is in the list of similar words
    similar_word_list = [word] + [sim_word for sim_word, _ in similar_words]
    
    # printing two lists for easy copy/pasting
    formatted_list = f"UNcurated_list_{word} = {similar_word_list}"
    removed_words_list = f"removed_words_{word} = []"
    
    print(formatted_list)
    print(removed_words_list)

# %%
generate_similar_words('extreme')
# Out:
# UNcurated_list_extreme = ['extreme', 'ultimate', 'dangerous', 'impact', 'action', 'intense', 'hardcore', 'insanity', 'speed', 'insane', 'effect', 'chaos', 'ultra', 'depression', 'physical', 'challenge', 'hard', 'violent', 'epic', 'experience', 'effects', 'tough', 'vortex', 'pressure', 'fitness', 'levels', 'edge', 'gaming', 'rage', 'huge', 'massive', 'such', 'heavy', 'emotional', 'gear', 'reality', 'serious', 'beyond', 'cyber', 'difference', 'competitive', 'outdoor', 'power', 'major', 'battle', 'severe', 'core', 'rush', 'fear', 'panic', 'flash']
# removed_words_extreme = []

# %% [markdown]
# ### Below I copied the above output and kept the words related to my semantic meaning for 'extreme' and moved the others to another list

# %%
curated_list_extreme = ['extreme',  'dangerous',  'hardcore', 'insanity', 
                           'insane', 'chaos',  'violent']
removed_words_extreme = ['ultimate', 'impact', 'action', 'intense','speed','effect','ultra', 'depression', 'physical', 'challenge', 'hard',
                        'epic', 'experience', 'effects', 'tough', 'vortex', 'pressure', 'fitness', 'levels', 
                        'edge', 'gaming', 'rage', 'huge', 'massive', 'such', 'heavy', 'emotional', 'gear', 'reality', 'serious',
                        'beyond', 'cyber', 'difference', 'competitive', 'outdoor', 'power', 'major', 'battle', 'severe', 'core', 
                        'rush', 'fear', 'panic', 'flash']

# %%
def compute_average_vector(words, model):
    vectors = []
    for word in words:
        if word in model.key_to_index:  # Check if the word is in the GloVe model
            vectors.append(model[word])
    if vectors:
        return np.mean(vectors, axis=0)  # Compute the average vector
    else:
        return np.zeros(model.vector_size)  # Return a zero vector if no words are found in the model

# %%
def find_similar_to_average(average_vector, model, topn=100):
    # Find words similar to the average vector
    similar_words = model.similar_by_vector(average_vector, topn=topn)

    # Extract just the words from the returned tuples
    words = [word for word, similarity in similar_words]

    return words

# %% [markdown]
# ### Once the curated and removed word lists have been developed, the following program will return the most semantically similar words to the ones on curated list and remove the words semantically similar to the removed words list.

# %%
def find_semantically_similar_words(curated_list, removed_list, topn=1000, similarity_threshold=0.5):
    # Compute average vectors for curated and removed lists
    average_vector_curated = compute_average_vector(curated_list, glove_model)
    average_vector_removed = compute_average_vector(removed_list, glove_model)
    
    # Find similar words to the curated list's average vector
    candidates = find_similar_to_average(average_vector_curated, glove_model, topn=topn)

    # Initialize a list to hold filtered candidates
    filtered_candidates = []

    for candidate in candidates:
        # Calculate similarity to the curated list's average
        sim_to_curated = np.dot(average_vector_curated, glove_model[candidate]) / (np.linalg.norm(average_vector_curated) * np.linalg.norm(glove_model[candidate]))
        
        # Calculate similarity to the removed list's average
        sim_to_removed = np.dot(average_vector_removed, glove_model[candidate]) / (np.linalg.norm(average_vector_removed) * np.linalg.norm(glove_model[candidate]))
        
        # Filter based on similarity thresholds
        if sim_to_curated > sim_to_removed and sim_to_removed < similarity_threshold:
            filtered_candidates.append(candidate)

    return filtered_candidates

# %%
extreme_ssim = find_semantically_similar_words(curated_list_extreme, removed_words_extreme, topn=100, similarity_threshold=.85)
print(extreme_ssim)
# Out:
# ['extreme', 'insane', 'dangerous', 'violent', 'chaos', 'insanity', 'crazy', 'hardcore', 'deadly', 'rage', 'brutal', 'scary', 'psycho', 'strange', 'badass', 'causing', 'evil', 'violence', 'killer', 'torture', 'freak', 'escape', 'raging', 'nightmare', 'terrible', 'reckless', 'killing']

# %%
curated_list_extreme = ['extreme', 'radical', 'extremist', 'extremists', 'extremism','dangerous', 'insanity', 'insane', 'chaos', 'violent', 
                       'far-right', 'rightwing', 'right-wing', 'anti-choice', 'homophobic', 'bigot', 'bigoted', 'MAGA', 'violent',
                       'insurrection','xenophobic','fascists','oppressive','authoritarian','divisive', 'anti-gay','misogynistic',
                       'deranged', 'hateful','anti-democratic','anti-democracy','conspiracy', 'conspiratorial','QAnon', 'insurrectionist']
removed_words_extreme = ['ultimate', 'impact', 'action', 'intense','speed','effect','ultra', 'depression', 'physical', 'challenge', 'hard',
                        'epic', 'experience', 'effects', 'tough', 'vortex', 'pressure', 'fitness', 'levels', 
                        'edge', 'gaming', 'rage', 'huge', 'massive', 'such', 'heavy', 'emotional', 'gear', 'reality', 'serious',
                        'beyond', 'cyber', 'difference', 'competitive', 'outdoor', 'power', 'major', 'battle', 'severe', 'core', 
                        'rush', 'fear', 'panic', 'flash', 'kinky', 'badass', 'dubstep', 'porn','evangelicals', 'jihadist','left-wing',
                        'leftist','elitist', 'marxist', 'communist',]

# %%
extreme_ssim = find_semantically_similar_words(curated_list_extreme, removed_words_extreme, topn= 50, similarity_threshold=.7)
print(extreme_ssim)
# Out:
# ['right-wing', 'leftist', 'extremists', 'extremist', 'misogynist', 'reactionary', 'divisive', 'xenophobic', 'homophobic', 'fascist', 'left-wing', 'rhetoric', 'misogynistic', 'marxist', 'bigots', 'sexist', 'ideological', 'partisan', 'bigoted', 'communist', 'elitist', 'extremism', 'murderous', 'religious', 'ideology', 'socialist', 'racists', 'oppressive', 'anti-american', 'zionist', 'bigot', 'fascists', 'conservative', 'conservatives', 'moronic', 'populist', 'pandering', 'racist', 'hateful', 'rightwing', 'idiotic', 'authoritarian', 'hypocrisy', 'hypocritical', 'fundamentalists', 'crazed', 'bigotry', 'liberals', 'fascism']

# %% [markdown]
# ### The below functions searches through the corpus of our candidates' tweets for any mention of the words on the curated list. It counts the tweets that have a hit and divides by the total sum tweets of the corpus.
# ### It also records the index of the tweets for observation

# %%
def analyze_word_presence(curated_list, tweets_mgp, tweets_deluzio, results_df):
    tokenized_curated_list = [preprocess_text(w)[0] for w in curated_list if preprocess_text(w)]

    relevant_tweets_mgp = []
    relevant_tweets_deluzio = []

    for idx, tweet in tweets_mgp.items():
        if any(w in tweet for w in tokenized_curated_list):
            relevant_tweets_mgp.append(idx)

    for idx, tweet in tweets_deluzio.items():
        if any(w in tweet for w in tokenized_curated_list):
            relevant_tweets_deluzio.append(idx)

    mgp_Proportion = len(relevant_tweets_mgp) / len(tweets_mgp)
    deluzio_Proportion = len(relevant_tweets_deluzio) / len(tweets_deluzio)

    # DataFrame for the current analysis
    result_df = pd.DataFrame({
        'Semantically_Similar_Words': [', '.join(curated_list)],
        'MGP_Proportion': [mgp_Proportion],
        'MGP_Relevant_Tweets': [relevant_tweets_mgp],
        'Deluzio_Proportion': [deluzio_Proportion],
        'Deluzio_Relevant_Tweets': [relevant_tweets_deluzio]
    })
    
    # Append the new results to the existing DataFrame and return
    updated_results_df = pd.concat([results_df, result_df], ignore_index=True)
    return updated_results_df

# %% [markdown]
# ### Preprocessing and applying line breaks into tweets for rendering

# %%
mgp_tweets['processed_tweets']=mgp_tweets['text'].apply(preprocess_text)
deluzio_tweets['processed_tweets']=deluzio_tweets['text'].apply(preprocess_text)
mgp_tweets['tweet_text_with_breaks'] = mgp_tweets['text'].apply(insert_line_breaks)
deluzio_tweets['tweet_text_with_breaks'] = deluzio_tweets['text'].apply(insert_line_breaks)

# %%
# empty DataFrame to hold all results
all_results_df = pd.DataFrame()

# %%
MGP = mgp_tweets['processed_tweets']
deluzio = deluzio_tweets['processed_tweets']

analyze_word_presence(curated_list_extreme, MGP, deluzio, all_results_df)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                            Semantically_Similar_Words  \
# 0  extreme, radical, extremist, extremists, extremism, dangerous, insanity, insane, chaos, violent, far-right, rightwing, right-wing, anti-choice, homophobic, bigot, bigoted, MAGA, violent, insurrection, xenophobic, fascists, oppressive, authoritarian, divisive, anti-gay, misogynistic, deranged, hateful, anti-democratic, anti-democracy, conspiracy, conspiratorial, QAnon, insurrectionist
#
#    MGP_Proportion  \
# 0        0.119289
#
#                                                                                                                                                                                                                       MGP_Relevant_Tweets  \
# 0  [21, 58, 60, 81, 99, 101, 118, 125, 126, 129, 143, 146, 149, 152, 165, 177, 191, 194, 195, 205, 207, 214, 222, 235, 240, 245, 254, 260, 268, 270, 274, 279, 294, 298, 300, 302, 303, 313, 316, 319, 322, 328, 332, 341, 347, 374, 391]
#
#    Deluzio_Proportion  \
# 0            0.094778
#
#                                                                                                                                                                                                                         Deluzio_Relevant_Tweets
# 0  [13, 20, 28, 31, 37, 39, 60, 62, 97, 106, 112, 115, 116, 120, 129, 131, 169, 177, 178, 186, 195, 196, 200, 202, 235, 254, 295, 306, 309, 318, 332, 334, 341, 343, 354, 357, 371, 375, 378, 394, 398, 423, 442, 456, 457, 473, 478, 486, 488]

# %%
generate_similar_words('volunteer')
# Out:
# UNcurated_list_volunteer = ['volunteer', 'volunteers', 'volunteering', 'abroad', 'community', 'charity', 'register', 'intern', 'students', 'internship', 'student', 'interns', 'donate', 'outreach', 'programs', 'fundraising', 'fundraiser', 'opportunity', 'assistance', 'staff', 'scholarship', 'donation', 'donations', 'aid', 'participate', 'join', 'fund', 'visit', 'graduate', 'helping', 'benefit', 'nurses', 'nonprofit', 'apply', 'organization', 'help', 'shelter', 'non-profit', 'job', 'rescue', 'youth', 'resources', 'support', 'contribute', 'needed', 'hire', 'sponsor', 'assistant', 'sponsors', 'charities', 'organizations']
# removed_words_volunteer = []

# %%
curated_list_volunteer = ['volunteer', 'volunteers', 'volunteering', 'community', 'register',  
                             'donate', 'outreach',  'fundraising', 'fundraiser', 
                             'donation', 'donations', 'aid', 'participate', 'register',
                            'join', 'fund', 'support', 'canvass', 'sign-up',
                            'help',  'support', 'contribute', 'needed', 
                            'hire', ]
removed_words_volunteer = [ 'abroad','charity','intern', 'students','internship', 'student', 'interns','programs','opportunity',
                          'assistance', 'staff', 'scholarship','visit', 'graduate', 'helping', 'benefit', 'nurses', 'nonprofit',
                           'apply', 'organization', 'shelter', 'non-profit', 'job', 'rescue', 'youth', 'resources', 'sponsor', 
                           'assistant', 'sponsors', 'charities', 'organizations']

# %%
volunteer_ssim = find_semantically_similar_words(curated_list_volunteer, removed_words_volunteer, topn=200, similarity_threshold=.7)
print(volunteer_ssim)
# Out:
# ['donations', 'donate', 'donation', 'fundraiser', 'campaign', 'contribute', 'help', 'raise', 'charities', 'participate', 'join', 'visit', 'receive', 'initiative', 'our', 'supporting', 'sponsors', 'donors', 'offer', 'awareness', 'raising', 'proceeds', 'donating', 'ensure', 'promoting', 'relief', 'us', 'event', 'sponsored', 'pledge', 'efforts', 'details', 'joining', 'annual', 'share', 'pay', 'any', 'participating', 'registration', 'helped', 'sponsorship', 'attending', 'giving', 'families', 'donated', 'sponsor', 'should', 'access', 'behalf', 'membership', 'will', 'for', 'deliver', 'bring', 'anyone', 'helps', 'nonprofits', 'rescue', 'petition', 'earn', 'need', 'campaigns', 'promotion', 'provided', 'encourage', 'save', 'give', 'discuss', 'competition', 'check', 'improve', 'further', 'thousands', 'must', 'victims', 'forward', 'increase', 'here', 'sign', 'also', 'build', 'incentive', 'spread', 'contribution', 'visitors', 'challenge', 'participants', 'another', 'address', 'could', 'saving', 'each', 'include', 'every', 'reward', 'raffle', 'grassroots']

# %%
curated_list_volunteer = ['volunteer', 'volunteers', 'volunteering', 'register','donate', 'donations', 
                          'donation', 'fundraiser', 'contribute', 'raise', 'join', 'canvass', 'canvasser', 'canvassers',
                          'knock', 'support', 'supporters', 'outreach',  'fundraising', 'participate','raising', 
                          'donating','fundraise', 'pledge', 'contribution', 'contributions','organize', 'organizing', 
                          'donor', 'donors']
removed_words_volunteer = [ 'abroad','charity','intern', 'students','internship', 'student', 'interns','programs','opportunity',
                          'assistance', 'staff', 'scholarship','visit', 'graduate', 'helping', 'benefit', 'nurses', 'nonprofit',
                           'apply', 'organization', 'shelter', 'non-profit', 'job', 'rescue', 'youth', 'resources', 'sponsor', 
                           'assistant', 'sponsors', 'charities', 'organizations']

# %%
analyze_word_presence(curated_list_volunteer, MGP, deluzio, all_results_df)
# Out:
#                                                                                                                                                                                                                                                                                                 Semantically_Similar_Words  \
# 0  volunteer, volunteers, volunteering, register, donate, donations, donation, fundraiser, contribute, raise, join, canvass, canvasser, canvassers, knock, support, supporters, outreach, fundraising, participate, raising, donating, fundraise, pledge, contribution, contributions, organize, organizing, donor, donors
#
#    MGP_Proportion  \
# 0        0.243655
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         MGP_Relevant_Tweets  \
# 0  [1, 2, 10, 13, 19, 27, 28, 38, 44, 45, 51, 60, 65, 69, 81, 82, 83, 87, 88, 91, 95, 98, 100, 105, 111, 113, 115, 120, 125, 126, 130, 135, 138, 148, 152, 154, 156, 158, 159, 163, 167, 168, 184, 185, 190, 194, 196, 205, 212, 228, 230, 231, 232, 234, 239, 241, 243, 249, 250, 257, 264, 266, 270, 275, 276, 280, 285, 287, 293, 299, 301, 304, 305, 315, 321, 322, 323, 332, 335, 338, 339, 342, 345, 348, 349, 352, 358, 367, 370, 372, 375, 384, 387, 389, 392, 393]
#
#    Deluzio_Proportion  \
# 0            0.166344
#
#                                                                                                                                                                                                                                                                                                                                                                                                        Deluzio_Relevant_Tweets
# 0  [7, 13, 15, 19, 23, 25, 32, 36, 45, 52, 56, 60, 64, 67, 70, 82, 86, 95, 110, 111, 125, 126, 135, 138, 155, 157, 159, 160, 162, 163, 166, 175, 182, 184, 187, 188, 189, 195, 199, 207, 208, 211, 217, 223, 224, 236, 239, 243, 251, 256, 266, 268, 275, 283, 284, 289, 308, 322, 327, 332, 345, 346, 347, 361, 362, 366, 369, 375, 381, 386, 387, 396, 401, 410, 431, 432, 434, 435, 451, 453, 458, 467, 486, 487, 488, 499]

# %%
generate_similar_words('unions')
# Out:
# UNcurated_list_unions = ['unions', 'workers', 'corporations', 'conservatives', 'labour', 'republicans', 'democrats', 'policies', 'governments', 'organizations', 'advocates', 'coalition', 'activists', 'dems', 'minorities', 'tories', 'liberals', 'institutions', 'orgs', 'councils', 'employers', 'politicians', 'mps', 'government', 'leaders', 'employees', 'govts', 'pensions', 'organisations', 'senators', 'reforms', 'protesting', 'oppose', 'companies', 'libs', 'repubs', 'taxpayers', 'universities', 'gov', 'lobbyists', 'govt', 'immigrants', 'rights', 'congress', 'threaten', 'lawyers', 'firms', 'austerity', 'groups', 'ministers', 'immigration']
# removed_words_unions = []

# %%
curated_list_unions = ['unions', 'union', 'unionize','solidarity', 'tradecraft', 'labor','collective','strike', 'striking']
removed_words_unions = ['conservatives', 'labour', 'republicans', 'democrats', 'policies', 
                         'governments', 'organizations', 'advocates', 'coalition', 'activists', 'dems', 'minorities', 'tories', 
                         'liberals', 'institutions', 'orgs', 'councils', 'employers', 'politicians', 'mps', 'government', 'leaders',
                         'employees', 'govts', 'pensions', 'organisations', 'senators', 'reforms', 'protesting', 'oppose', 'companies', 
                         'libs', 'repubs', 'taxpayers', 'universities', 'gov', 'lobbyists', 'govt', 'immigrants', 'rights', 'congress', 
                         'threaten', 'lawyers', 'firms', 'austerity', 'groups', 'ministers', 'immigration']

# %%
unions_ssim = find_semantically_similar_words(curated_list_unions, removed_words_unions, topn=200, similarity_threshold=.7)
print(unions_ssim)
# Out:
# ['protest', 'strike', 'labor', 'union', 'solidarity', 'protesting', 'striking', 'military', 'forces', 'protests', 'collective', 'rally', 'alliance', 'forced', 'rallies', 'defence', 'petition', 'lgbt', 'initiative', 'freedom', 'youth', 'ministry', 'veterans', 'against', 'pledge', 'israeli', 'prisoners', 'troops', 'community', 'movement', 'diversity', 'aid', 'partnership', 'defense', 'inclusion', 'continuing', 'representing', 'independence', 'camps', 'supporting', 'occupy', 'liberty', 'equality', 'historic', 'civil', 'support', 'transition', 'unity', 'volunteers', 'ukraine', 'worker', 'force', 'partnerships', 'soldiers', 'appeal', 'negotiations', 'embassy', 'strikes', 'demonstration', 'agreement', 'indigenous', 'development', 'army', 'execution', 'our', 'national', 'their', 'staff']

# %%
analyze_word_presence(curated_list_unions, MGP, deluzio, all_results_df)
# Out:
#                                                              Semantically_Similar_Words  \
# 0  unions, union, unionize, solidarity, tradecraft, labor, collective, strike, striking
#
#    MGP_Proportion  \
# 0        0.032995
#
#                                               MGP_Relevant_Tweets  \
# 0  [50, 75, 98, 110, 114, 145, 261, 263, 264, 265, 266, 364, 377]
#
#    Deluzio_Proportion  \
# 0            0.160542
#
#                                                                                                                                                                                                                                                                                                                                                                                                   Deluzio_Relevant_Tweets
# 0  [10, 16, 24, 32, 42, 45, 67, 84, 91, 101, 107, 110, 117, 128, 138, 140, 153, 155, 163, 164, 165, 166, 175, 179, 183, 188, 218, 221, 222, 224, 225, 234, 236, 245, 246, 247, 249, 256, 272, 276, 277, 278, 279, 282, 284, 286, 289, 296, 297, 302, 303, 315, 319, 321, 325, 333, 351, 354, 355, 362, 387, 409, 419, 425, 443, 447, 451, 454, 459, 466, 470, 471, 472, 479, 480, 481, 482, 484, 487, 501, 502, 503, 512]

# %%
generate_similar_words('endorsement')
# Out:
# UNcurated_list_endorsement = ['endorsement', 'endorsements', 'endorses', 'sponsorship', 'promotional', 'campaign', 'shareholder', 'endorsing', 'advertisement', 'backers', 'exec', 'employee', 'naacp', 'donors', 'exclusive', 'endorsed', 're-election', 'endorse', 'signature', 'touts', 'sponsors', 'fundraisers', 'send-off', 'staffer', 'birther', 'touting', 'sponsored', 'executive', 'reveals', 'milestone', 'staffers', 'promotion', 'one-time', 'employees', 'advertising', 'renewal', 'congressional', 'pro-gun', 'candidate', 'employer', 'backlash', 'execs', 'fansite', 'reelection', 'reps', 'auction', 'spao', 'executives', 'merchandise', 'anti-gun', 'turnaround']
# removed_words_endorsement = []

# %%
curated_list_endorsement = ['endorsement', 'endorsements', 'endorses', 'sponsorship',  
                            'endorsing',   'endorsed', 'sponsor','sponsoring',
                             'endorse',  'sponsors', 
                             'sponsored', ]
removed_words_endorsement = ['promotional', 'campaign','shareholder', 'advertisement','backers', 'exec', 
                             'employee', 'naacp', 'donors', 'exclusive','re-election','signature', 'touts',
                            'fundraisers', 'send-off', 'staffer', 'birther', 'touting','executive', 'reveals', 'milestone', 
                             'staffers', 'promotion', 'one-time', 'employees',
                            'advertising', 'renewal', 'congressional', 'pro-gun', 'candidate', 'employer', 
                            'backlash', 'execs', 'fansite', 'reelection', 'reps', 'auction', 'spao', 
                            'executives', 'merchandise', 'anti-gun', 'turnaround']

# %%
endorsement_ssim = find_semantically_similar_words(curated_list_endorsement, removed_words_endorsement, topn=200, similarity_threshold=.7)
print(endorsement_ssim)
# Out:
# ['sponsors', 'endorsed', 'sponsored', 'endorsing', 'sponsoring', 'endorse', 'endorses', 'contributions', 'promoting', 'fundraiser', 'sponsor', 'participating', 'announcing', 'donations', 'contributors', 'joining', 'ambassadors', 'non-profit', 'limbaugh', 'charities', 'charity', 'supporting', 'volunteers', 'participants', 'fundraise', 'donating', 'badges', 'advocating', 'funded', 'participate', 'attending', 'featured', 'participated', 'announce', 'interviewing', 'organisers', 'non-profits', 'vetting', 'offered', 'advertise', 'recognized', 'contribute', 'congratulate', 'introducing', 'showcasing', 'boycotting', 'representing', 'selected', 'eligible', 'backing', 'interested', 'contacted', 'sign-up', 'proceeds', 'qualified', 'promoter', 'co-chair', 'donated', 'filmmakers', 'benefiting', 'mailing', 'partnering', 'highlighting', 'suggested', 'gearing', 'qualify', 'provided']

# %%
analyze_word_presence(curated_list_endorsement, MGP, deluzio, all_results_df)
# Out:
#                                                                                                  Semantically_Similar_Words  \
# 0  endorsement, endorsements, endorses, sponsorship, endorsing, endorsed, sponsor, sponsoring, endorse, sponsors, sponsored
#
#    MGP_Proportion  \
# 0        0.053299
#
#                                                                                      MGP_Relevant_Tweets  \
# 0  [30, 69, 92, 96, 171, 172, 199, 275, 305, 309, 312, 314, 316, 338, 359, 360, 364, 370, 371, 375, 379]
#
#    Deluzio_Proportion  \
# 0             0.03675
#
#                                                                         Deluzio_Relevant_Tweets
# 0  [32, 73, 81, 110, 129, 135, 139, 160, 190, 195, 196, 225, 227, 228, 258, 275, 325, 340, 436]

# %%
generate_similar_words('protect')
# Out:
# UNcurated_list_protect = ['protect', 'protecting', 'allow', 'defend', 'protected', 'help', 'preserve', 'save', 'hide', 'privacy', 'support', 'us', 'children', 'their', 'protection', 'secure', 'protects', 'accept', 'them', 'aim', 'remove', 'care', 'deny', 'provide', 'ensure', 'prevent', 'restore', 'child', 'rights', 'carry', 'own', 'our', 'freedom', 'keep', 'citizens', 'choose', 'trust', 'allowed', 'strong', 'seek', 'destroy', 'neglect', 'hold', 'lives', 'threaten', 'share', 'control', 'claim', 'make', 'each', 'create']
# removed_words_protect = []

# %%
curated_list_protect = ['protect', 'protecting', 'defend', 'protected',  'preserve','protection', 'protects', 
                         'prevent', 'restore', 'rights','destroy', 'threaten', 'threatens','protecting','preventing', 'prevention', 'restrict',
                        'threatening', 'advocate', 'advocates','strengthen','weaken','rights', 'freedom', 'freedoms', 'constitutional']
removed_words_protect = ['allow','help', 'save', 'hide', 'privacy', 'support', 
                          'us', 'children', 'their', ]

# %%
protect_ssim = find_semantically_similar_words(curated_list_protect, removed_words_protect, topn=200, similarity_threshold=.7)
print(protect_ssim)
# Out:
# ['protecting', 'rights', 'ensure', 'defend', 'laws', 'prevent', 'advocates', 'citizens', 'government', 'democracy', 'threaten', 'protection', 'allowing', 'freedom', 'restrict', 'allows', 'freedoms', 'responsibility', 'protected', 'oppose', 'amendment', 'policies', 'constitutional', 'violence', 'minorities', 'preventing', 'protects', 'responsible', 'preserve', 'legislation', 'advocate', 'forced', 'attacks', 'policy', 'opposed', 'forces', 'attacking', 'humanity', 'military', 'terrorism', 'equal', 'authority', 'sovereignty', 'ownership', 'interests', 'threatening', 'political', 'threat', 'weapons', 'secure', 'unions', 'accountability', 'religious', 'harm', 'poverty', 'immigration', 'threatened', 'denying', 'politicians', 'abortion', 'forcing', 'compromise', 'constitution', 'law', 'restore', 'benefits', 'threatens', 'encourage', 'congress', 'defending', 'govt', 'destroying', 'environment', 'welfare', 'governments', 'workplace', 'assault', 'eliminate', 'criminals', 'liberties', 'workers', 'communities', 'liberty', 'leaders', 'oppression', 'marriage', 'ensuring', 'activists', 'conservatives', 'opposing', 'organization', 'equality', 'strengthen', 'weapon', 'organizations', 'values', 'targets', 'pledge', 'established', 'advocating', 'stance', 'states', 'threats', 'accountable', 'abandon', 'embrace', 'capitalism', 'requiring', 'uphold', 'victims', 'continuing', 'enforcement', 'providing', 'corporations', 'u.s.', 'undermine', 'ruling', 'so-called', 'demands', 'claims', 'christians', 'democratic', 'intervene', 'affect', 'supports', 'reforms', 'regulations', 'refusing', 'safeguard', 'regulation', 'principles', 'palestinians', 'lawyers', 'firearms', 'obamacare', 'violate', 'climate', 'punish', 'risks', 'immigrants', 'veterans', 'illegal', 'funds', 'controlled', 'dignity', 'torture', 'environmental', 'reform', 'israeli', 'funding', 'toward', 'justify', 'restricting', 'democrats']

# %%
analyze_word_presence(curated_list_protect, MGP, deluzio, all_results_df)
# Out:
#                                                                                                                                                                                                                                                       Semantically_Similar_Words  \
# 0  protect, protecting, defend, protected, preserve, protection, protects, prevent, restore, rights, destroy, threaten, threatens, protecting, preventing, prevention, restrict, threatening, advocate, advocates, strengthen, weaken, rights, freedom, freedoms, constitutional
#
#    MGP_Proportion  \
# 0        0.121827
#
#                                                                                                                                                                                                                      MGP_Relevant_Tweets  \
# 0  [5, 36, 46, 51, 84, 85, 88, 91, 95, 96, 105, 124, 136, 148, 173, 176, 180, 183, 184, 199, 204, 205, 213, 231, 239, 245, 254, 290, 297, 298, 300, 305, 309, 318, 321, 330, 336, 337, 340, 346, 356, 363, 365, 376, 377, 378, 384, 389]
#
#    Deluzio_Proportion  \
# 0            0.176015
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                   Deluzio_Relevant_Tweets
# 0  [5, 10, 24, 27, 28, 31, 38, 42, 58, 60, 61, 72, 86, 87, 96, 97, 106, 112, 116, 128, 130, 131, 133, 140, 142, 157, 163, 164, 172, 173, 177, 178, 188, 196, 198, 201, 202, 225, 227, 234, 235, 254, 258, 261, 275, 283, 286, 287, 296, 297, 306, 309, 311, 318, 332, 334, 341, 351, 357, 359, 362, 369, 371, 375, 378, 394, 400, 404, 405, 413, 415, 416, 417, 419, 423, 425, 442, 446, 448, 455, 456, 457, 459, 473, 478, 490, 493, 494, 498, 502, 507]

# %%
generate_similar_words('folks')
# Out:
# UNcurated_list_folks = ['folks', 'yall', 'ppl', 'peeps', 'these', 'niggas', 'mfs', 'everybody', 'people', 'cuz', 'gotta', 'ones', 'bunch', 'those', 'many', 'all', "y'", 'other', 'niggaz', 'they', 'few', 'them', 'talk', 'some', 'tryna', 'fuckers', 'smh', 'tell', 'especially', 'bitches', 'guess', 'where', 'there', 'fellas', 'bruh', 'plenty', 'aint', 'everyone', 'here', 'hoes', 'dumb', 'enough', 'keep', 'either', 'working', 'work', 'goin', 'lets', 'telling', 'let', 'lot']
# removed_words_folks = []

# %%
curated_list_folks = ['folks', 'folk', 'yall', 'class', 'small', 'average', 'regular', 'fellow',
                     'neighbor', 'neighbors',]

removed_words_folks= ['ones', 'know', 'hate', 'there', 'how', 'things', 'these', 'about', 'only', 'why', 'all', 'not', 'person', 
                         'friends', 'are', 'understand', 'that', 'especially', 'have', 'reason', 'you', 'way', 'like', 'lot', 'but', 
                         'niggas', 'mfs','anyone', 'really', "'re", 'if', 'thing', 'should', 'talk', 'where', 'us', 'trying', 'enough', 
                      'any', 'always','niggaz','fuckers','hoes', 'dumb','bitches']

# %%
folks_ssim = find_semantically_similar_words(curated_list_folks, removed_words_folks, topn=2000, similarity_threshold=.5)
print(folks_ssim)
# Out:
# ['neighborhood', 'neighbours', 'folk', 'local', 'upstairs', 'neighbour', 'activities', 'serving', 'broad', 'deaf', "ol'", 'adult', 'addition', 'workers', 'fella', 'employees', 'educated', 'obnoxious', 'yard', 'jewish', 'desk', 'owners', 'raising', 'audience', 'locals', 'native', 'dutch', 'elderly', 'roommates', 'southern', 'rooms', 'staff', 'meal', 'coolest', 'knocking', 'houses', 'families', 'cleaning', 'detroit', 'ohio', 'coworkers', 'buck', 'mornin', 'attacking', 'crib', 'pals', 'downstairs', 'productive', 'hispanic', 'easter', 'inviting', 'nite', 'farm', 'wives', 'meetings', 'businesses', 'minded', 'gentlemen', 'cities', 'networking', 'downtown', 'nigerian', 'grandparents', 'hallway', 'roof', 'niggers', 'grandmas', 'spoiled', 'wealthy', 'market', 'beers', 'quarter', 'apartment', 'professors', 'practices', 'greedy', 'bedroom', 'tradition', 'colleagues', 'customer']

# %%
analyze_word_presence(curated_list_folks, MGP, deluzio, all_results_df)
# Out:
#                                                        Semantically_Similar_Words  \
# 0  folks, folk, yall, class, small, average, regular, fellow, neighbor, neighbors
#
#    MGP_Proportion  \
# 0         0.06599
#
#                                                                                                                 MGP_Relevant_Tweets  \
# 0  [17, 44, 103, 127, 142, 153, 160, 235, 240, 248, 257, 270, 278, 284, 292, 295, 297, 310, 324, 335, 338, 353, 382, 384, 385, 390]
#
#    Deluzio_Proportion  \
# 0            0.141199
#
#                                                                                                                                                                                                                                                                                                                                       Deluzio_Relevant_Tweets
# 0  [1, 8, 20, 23, 24, 36, 40, 56, 72, 79, 81, 84, 89, 90, 91, 93, 98, 109, 120, 137, 154, 155, 157, 161, 173, 178, 192, 193, 200, 210, 213, 225, 230, 233, 241, 244, 265, 266, 271, 289, 292, 296, 303, 306, 321, 331, 337, 346, 352, 356, 357, 367, 368, 369, 392, 393, 396, 400, 407, 411, 414, 415, 435, 436, 438, 440, 443, 454, 456, 481, 487, 506, 516]

# %%
generate_similar_words('abortion')
# Out:
# UNcurated_list_abortion = ['abortion', 'abortions', 'marriage', 'parenthood', 'pro-life', 'contraception', 'rape', 'obamacare', 'homosexuality', 'prolife', 'rights', 'gosnell', 'amendment', 'legislation', 'same-sex', 'birth', 'prochoice', 'immigration', 'trafficking', 'laws', 'pregnancy', 'mandate', 'equality', 'constitutional', 'infanticide', 'anti-gay', 'medicaid', 'catholic', 'circumcision', 'repeal', 'discrimination', 'stance', 'medicare', 'policy', 'divorce', 'illegal', 'unconstitutional', 'violence', 'religious', 'republican', 'democracy', 'dowry', 'slavery', 'pedophilia', 'advocates', 'scotus', 'prayto', 'harassment', 'adoption', 'pro-choice', 'disability']
# removed_words_abortion = []

# %%
curated_list_abortion = ['abortion', 'abortions', 'parenthood', 'pro-life', 'contraception', 'rape', 'incest',
                            'prolife',  'birth', 'prochoice', 'pro-choice','pregnancy', 
                           'adoption', 'pregnant', 'birthing', 'pregnancy', 'fertility', 
                         'aborted','surrogate', 'contraceptive', 'parenting', 'conceive', 'conception',
                         'fertility','ivf','miscarriage',  'contraceptives', 'abstinence',"mother", "motherhood",
                        'pregnancy', 'breastfeeding', 'pregnancies', 'contraceptives', 'fertility', 'birth', 'prolife', 
                         'surrogate', 'pregnancy', 'breastfeeding', 'pregnancies', 'contraceptives', 'fertility', 'birth', 'premature', 
                         'surrogate', 'miscarriage', 'ivf', ]
removed_words_abortion = [ 'marriage','obamacare', 'homosexuality', 'rights', 'gosnell', 'amendment', 'legislation', 'same-sex','equality', 
                          'constitutional', 'infanticide',  'anti-gay', 'medicaid', 'catholic', 'circumcision', 'repeal',
                          'discrimination', 'stance', 'medicare', 'policy', 'divorce', 'illegal', 'unconstitutional', 
                          'violence', 'religious', 'republican', 'democracy', 'dowry', 'slavery', 'pedophilia', 
                          'advocates', 'prayto', 'harassment',]

# %%
abortion_ssim = find_semantically_similar_words(curated_list_abortion, removed_words_abortion, topn=200, similarity_threshold=.6)
print(abortion_ssim)
# Out:
# ['pregnancy', 'breastfeeding', 'pregnancies', 'fertility', 'premature', 'birth', 'miscarriage', 'ivf', 'contraceptives', 'motherhood', 'surrogate', 'vaccine', 'c-section', 'epilepsy', 'births', 'parenting', 'paedophilia', 'birthing', 'infertility', 'pregnant', 'childbirth', 'diagnosis', 'orgasms', 'gosnell', 'prolife', 'breast', 'contraceptive', 'postpartum', 'infanticide', 'sterilization', 'patients', 'preggo', 'aborted', 'obesity', 'mortality', 'unborn', 'breastfeed', 'aging', 'infants', 'empowerment', 'midwives', 'autism', 'breastcancer', 'birthcontrol', 'conception', 'maternity', 'prevention', 'lesbianism', 'schizophrenia', 'prochoice', 'hiv', 'malnutrition', 'statutory', 'surgeries', 'enlargement', 'incest', 'illness', 'clinics', 'fgm', 'abstinence', 'ovarian', 'infidelity', 'kidnapping', 'mothers', 'preterm', 'asbestos', 'surrogacy', 'dementia', 'seizure', 'orgasm', 'ultrasounds', 'pro-choice', 'diabetic', 'referred', 'prevented', 'dysfunction', 'procreation', 'preventative', 'disease', 'mammogram', 'visitation', 'narcissism', 'women', 'child', 'prostate', 'thyroid', 'vasectomy', 'doula', 'treatment', 'paternity', 'overweight', 'methadone', 'vaccination', 'colonoscopy', 'preggers', 'homeopathy', 'endometriosis', 'treatments', 'chastity', 'ultrasound', 'epidemic', 'symptoms', 'children', 'abusers', 'objectification', 'abusive', 'paedophile', 'gonorrhea', 'sodomy', 'priests', 'pill', 'midlife', 'caesarean', 'adopting', 'melanoma', 'conceived', 'counseling', 'adults', 'prescriptions', 'fostering', 'substance', 'uterus', 'engagements', 'doctors', 'enhancement', 'mastectomy', 'toddlers', 'disorders', 'fetuses', 'daughters', 'asthma', 'longevity', 'declining', 'unmarried', 'assimilation', 'acceptance', 'elderly', 'self-harming', 'arousal', 'erectile', 'awareness', 'nurses', 'celiac', 'depression', 'ugandans', 'alcoholism', 'mammograms', 'boomers', 'concussion', 'sids', 'physicians']

# %%
analyze_word_presence(curated_list_abortion, MGP, deluzio, all_results_df)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Semantically_Similar_Words  \
# 0  abortion, abortions, parenthood, pro-life, contraception, rape, incest, prolife, birth, prochoice, pro-choice, pregnancy, adoption, pregnant, birthing, pregnancy, fertility, aborted, surrogate, contraceptive, parenting, conceive, conception, fertility, ivf, miscarriage, contraceptives, abstinence, mother, motherhood, pregnancy, breastfeeding, pregnancies, contraceptives, fertility, birth, prolife, surrogate, pregnancy, breastfeeding, pregnancies, contraceptives, fertility, birth, premature, surrogate, miscarriage, ivf
#
#    MGP_Proportion  \
# 0        0.083756
#
#                                                                                                                                                  MGP_Relevant_Tweets  \
# 0  [25, 56, 64, 96, 103, 129, 140, 145, 149, 160, 180, 182, 191, 194, 199, 214, 234, 247, 272, 273, 283, 284, 289, 290, 321, 325, 328, 330, 337, 354, 355, 356, 386]
#
#    Deluzio_Proportion  \
# 0            0.071567
#
#                                                                                                                                                                Deluzio_Relevant_Tweets
# 0  [10, 20, 28, 38, 60, 80, 104, 112, 115, 131, 169, 172, 202, 203, 226, 232, 257, 258, 261, 281, 295, 306, 318, 354, 357, 371, 378, 398, 423, 456, 457, 473, 478, 493, 494, 495, 496]

# %%
generate_similar_words('manufacture')
# Out:
# UNcurated_list_manufacture = ['manufacture', 'manufacturers', 'undertake', 'suppliers', 'implement', 'packaging', 'distributors', 'discounting', 'manufactured', 'components', 'propagate', 'apropos', 'manufacturer', 'legitimize', 'multinational', 'aluminium', 'specialised', 'primarily', 'anent', 'constructing', 'designed', 'fabrication', 'containers', 'high-quality', 'specialize', 'refurbish', 'distribute', 'construct', 'export', 'populate', 'machinery', 'revolutionize', 'oversee', 'equate', 'synthetic', 'products', 'assembling', 'imbibe', 'assembled', 'salvage', 'specialise', 'catalysts', 'measuring', 'accommodate', 'bulk', 'implementing', 'compensate', 'assimilate', 'leveraging', 'equipments', 'demonize']
# removed_words_manufacture = []

# %%
curated_list_manufacture = ['manufacture', 'manufacturers',  'manufacturer', 'manufacturing','manufactured','jobs', 'job','infrastructure', 
                            'construction','industry','industries', 'produce', 'products', ]
removed_words_manufacture = ['undertake', 'suppliers', 'implement', 'packaging', 'distributors', 
                              'discounting',  'components', 'propagate', 'apropos','legitimize', 'aluminium', 'specialised', 
                             'primarily', 'anent', 'constructing', 'designed', 
                              'fabrication', 'containers', 'high-quality', 'specialize', 'refurbish', 'distribute', 'construct', 
                              'export', 'populate', 'machinery', 'revolutionize', 'oversee', 'equate', 'synthetic', 'products', 
                              'assembling', 'imbibe', 'assembled', 'salvage', 'specialise', 'catalysts', 'measuring', 'accommodate', 
                              'bulk', 'implementing', 'compensate', 'assimilate', 'leveraging', 'equipments', 'demonize']

# %%
manufacture_ssim = find_semantically_similar_words(curated_list_manufacture, removed_words_manufacture, topn=200, similarity_threshold=.8)
print(manufacture_ssim)
# Out:
# ['companies', 'manufacturing', 'industry', 'company', 'retail', 'products', 'product', 'production', 'development', 'services', 'supply', 'technology', 'systems', 'equipment', 'businesses', 'construction', 'infrastructure', 'housing', 'suppliers', 'business', 'manufacturer', 'manufacturers', 'industries', 'solutions', 'resources', 'engineers', 'firms', 'export', 'distribution', 'sales', 'advertising', 'investment', 'market', 'hiring', 'workers', 'jobs', 'corporate', 'brands', 'based', 'consumers', 'inc.', 'prices', 'packaging', 'engineering', 'enterprise', 'executive', 'growth', 'materials', 'consumer', 'resource', 'hardware', 'pharmaceutical', 'electronics', 'firm', 'corporation', 'engineer', 'automotive', 'management', 'projects', 'mining', 'building', 'software', 'offers', 'operations', 'environmental', 'facility', 'transportation', 'contracts', 'innovation', 'provide', 'customers', 'employees', 'sustainable', 'improvement', 'economy', 'specialist', 'technologies', 'quality', 'department', 'executives', 'financial', 'research', 'providers', 'costs', 'pricing', 'professionals', 'insurance', 'system', 'llc', 'careers', 'profits', 'customer', 'tech', 'cost', 'process', 'built', 'consulting', 'oil', 'procurement', 'representative', 'vendors', 'retailers', 'strategic', 'leading', 'investments', 'healthcare', 'communications', 'brand', 'automation', 'electrical', 'employment', 'service', 'designed', 'specialists', 'property', 'innovative', 'sourcing', 'banking', 'ltd', 'partnership', 'provides', 'logistics', 'affordable', 'agencies', 'parts', 'benefits', 'factory', 'equity', 'inventory', 'environment', 'utility', 'value', 'agriculture', 'analyst', 'fuel', 'job', 'owners', 'printing', 'r&d', 'providing', 'efficiency', 'purchasing', 'build', 'funding', 'industrial', 'finance', 'plant', 'tools', 'deals', 'strategy', 'organization', 'electricity', 'producing', 'revenue', 'fund', 'markets', 'government', 'farmers', 'u.s.', 'technician', 'consultant', 'managers', 'renewable', 'contractors', 'organizations', 'emerging', 'assets', 'consultants', 'stores', 'including', 'facilities', 'agricultural', 'supplies', 'network', 'expansion', 'asset', 'price', 'developers', 'sectors', 'properties', 'retailer', 'pharma', 'employee', 'communities', 'selling', 'economic', 'vehicles', 'telecoms', 'employers', 'partners', 'operating', 'health', 'exec', 'reviews', 'electronic', 'education', 'developed']

# %%
analyze_word_presence(curated_list_manufacture, MGP, deluzio, all_results_df)
# Out:
#                                                                                                                                 Semantically_Similar_Words  \
# 0  manufacture, manufacturers, manufacturer, manufacturing, manufactured, jobs, job, infrastructure, construction, industry, industries, produce, products
#
#    MGP_Proportion  \
# 0        0.035533
#
#                                                  MGP_Relevant_Tweets  \
# 0  [21, 33, 66, 81, 94, 112, 200, 204, 254, 297, 305, 361, 381, 388]
#
#    Deluzio_Proportion  \
# 0            0.125725
#
#                                                                                                                                                                                                                                                                                                       Deluzio_Relevant_Tweets
# 0  [8, 32, 35, 42, 63, 64, 68, 69, 91, 94, 101, 102, 107, 110, 128, 151, 162, 164, 165, 167, 188, 191, 221, 224, 234, 246, 259, 269, 270, 272, 276, 281, 290, 293, 298, 300, 302, 306, 316, 323, 325, 326, 333, 355, 358, 374, 383, 386, 387, 388, 408, 418, 438, 443, 451, 454, 460, 468, 469, 470, 471, 479, 482, 484, 492]

# %%
curated_list_china = ['china', 'chinese', 'overseas','outsourcing', 'outsource']

# %%
analyze_word_presence(curated_list_china, MGP, deluzio, all_results_df)
# Out:
#                          Semantically_Similar_Words  MGP_Proportion  \
# 0  china, chinese, overseas, outsourcing, outsource        0.002538
#
#   MGP_Relevant_Tweets  Deluzio_Proportion  \
# 0               [125]            0.054159
#
#                                                                                                                  Deluzio_Relevant_Tweets
# 0  [8, 63, 68, 69, 91, 94, 150, 151, 162, 167, 223, 259, 263, 293, 298, 300, 325, 358, 408, 443, 445, 447, 451, 454, 460, 461, 470, 492]

# %%
generate_similar_words('corporations')
# Out:
# UNcurated_list_corporations = ['corporations', 'governments', 'companies', 'politicians', 'lobbyists', 'govts', 'organizations', 'unions', 'ceos', 'capitalist', 'institutions', 'capitalists', 'businesses', 'capitalism', 'firms', 'billionaires', 'consumers', 'corporate', 'corporates', 'wealthy', 'government', 'taxpayers', 'organisations', 'bureaucrats', 'lobbying', 'multinationals', 'conservatives', 'policies', 'bankers', 'orgs', 'liberals', 'corrupt', 'taxes', 'budgets', 'subsidies', 'societies', 'profits', 'criminals', 'americans', 'multinational', 'councils', 'individuals', 'regulations', 'employers', 'economies', 'socialists', 'banks', 'entities', 'democrats', 'taxing', 'citizens']
# removed_words_corporations = []

# %%
curated_list_corporations = ['corporations', 'lobbyists', 'ceo', 'lobbyist','executives', 
                               'ceos', 'billionaires', 'PAC', 'PACs','super-pac', 'millionaires',
                               'consumers', 'corporate', 'corporates', 'wealthy', 'taxpayers', 
                                'lobbying', 'multinationals',  'corrupt', 'taxes', 'profit', 'profits', 
                               ]
removed_words_corporations = ['governments', 'companies', 'politicians','govts', 'organizations', 'unions',
                              'capitalist', 'institutions', 'capitalists', 'businesses', 'capitalism', 'firms',
                             'bureaucrats', 'conservatives', 'policies', 'bankers', 'orgs', 
                               'liberals','subsidies', 'societies', 'americans','socialists', 'banks', 
                              'entities', 'democrats', 'taxing', 'citizens','councils', 'individuals','regulations', 
                              'employers', 'economies']

# %%
analyze_word_presence(curated_list_corporations, MGP, deluzio, all_results_df)
# Out:
#                                                                                                                                                                                                     Semantically_Similar_Words  \
# 0  corporations, lobbyists, ceo, lobbyist, executives, ceos, billionaires, PAC, PACs, super-pac, millionaires, consumers, corporate, corporates, wealthy, taxpayers, lobbying, multinationals, corrupt, taxes, profit, profits
#
#    MGP_Proportion  \
# 0        0.035533
#
#                                                      MGP_Relevant_Tweets  \
# 0  [77, 127, 131, 171, 197, 204, 261, 270, 276, 374, 377, 385, 387, 392]
#
#    Deluzio_Proportion  \
# 0            0.189555
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Deluzio_Relevant_Tweets
# 0  [8, 12, 24, 29, 34, 35, 50, 53, 54, 58, 63, 64, 76, 85, 91, 92, 93, 99, 100, 101, 108, 109, 111, 119, 121, 127, 145, 151, 152, 162, 163, 164, 166, 167, 187, 188, 192, 198, 204, 205, 207, 214, 215, 216, 218, 221, 223, 229, 232, 233, 238, 246, 251, 252, 256, 259, 260, 281, 283, 296, 300, 305, 317, 322, 333, 342, 346, 377, 381, 385, 389, 400, 411, 419, 427, 429, 431, 438, 441, 443, 447, 448, 450, 454, 461, 462, 466, 470, 480, 481, 483, 484, 485, 488, 489, 504, 513, 516]

# %%
import importlib
importlib.reload(pd)  # Reload the pandas library

# creating an empty DataFrame again
all_results_df = pd.DataFrame()

# %%
all_results_df = analyze_word_presence(curated_list_extreme, MGP, deluzio, all_results_df)
all_results_df = analyze_word_presence(curated_list_volunteer, MGP, deluzio, all_results_df)
all_results_df = analyze_word_presence(curated_list_unions, MGP, deluzio, all_results_df)
all_results_df = analyze_word_presence(curated_list_endorsement, MGP, deluzio, all_results_df)
all_results_df = analyze_word_presence(curated_list_protect, MGP, deluzio, all_results_df)
all_results_df = analyze_word_presence(curated_list_folks, MGP, deluzio, all_results_df)
all_results_df = analyze_word_presence(curated_list_abortion, MGP, deluzio, all_results_df)
all_results_df = analyze_word_presence(curated_list_manufacture, MGP, deluzio, all_results_df)
all_results_df = analyze_word_presence(curated_list_china, MGP, deluzio, all_results_df)
all_results_df = analyze_word_presence(curated_list_corporations, MGP, deluzio, all_results_df)

# %%
all_results_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Semantically_Similar_Words  \
# 0                                                                                                                                           extreme, radical, extremist, extremists, extremism, dangerous, insanity, insane, chaos, violent, far-right, rightwing, right-wing, anti-choice, homophobic, bigot, bigoted, MAGA, violent, insurrection, xenophobic, fascists, oppressive, authoritarian, divisive, anti-gay, misogynistic, deranged, hateful, anti-democratic, anti-democracy, conspiracy, conspiratorial, QAnon, insurrectionist
# 1                                                                                                                                                                                                                      volunteer, volunteers, volunteering, register, donate, donations, donation, fundraiser, contribute, raise, join, canvass, canvasser, canvassers, knock, support, supporters, outreach, fundraising, participate, raising, donating, fundraise, pledge, contribution, contributions, organize, organizing, donor, donors
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                         unions, union, unionize, solidarity, tradecraft, labor, collective, strike, striking
# 3                                                                                                                                                                                                                                                                                                                                                                                                                     endorsement, endorsements, endorses, sponsorship, endorsing, endorsed, sponsor, sponsoring, endorse, sponsors, sponsored
# 4                                                                                                                                                                                                                                                                protect, protecting, defend, protected, preserve, protection, protects, prevent, restore, rights, destroy, threaten, threatens, protecting, preventing, prevention, restrict, threatening, advocate, advocates, strengthen, weaken, rights, freedom, freedoms, constitutional
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                               folks, folk, yall, class, small, average, regular, fellow, neighbor, neighbors
# 6  abortion, abortions, parenthood, pro-life, contraception, rape, incest, prolife, birth, prochoice, pro-choice, pregnancy, adoption, pregnant, birthing, pregnancy, fertility, aborted, surrogate, contraceptive, parenting, conceive, conception, fertility, ivf, miscarriage, contraceptives, abstinence, mother, motherhood, pregnancy, breastfeeding, pregnancies, contraceptives, fertility, birth, prolife, surrogate, pregnancy, breastfeeding, pregnancies, contraceptives, fertility, birth, premature, surrogate, miscarriage, ivf
# 7                                                                                                                                                                                                                                                                                                                                                                                      manufacture, manufacturers, manufacturer, manufacturing, manufactured, jobs, job, infrastructure, construction, industry, industries, produce, products
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             china, chinese, overseas, outsourcing, outsource
# 9                                                                                                                                                                                                                                                                                                                  corporations, lobbyists, ceo, lobbyist, executives, ceos, billionaires, PAC, PACs, super-pac, millionaires, consumers, corporate, corporates, wealthy, taxpayers, lobbying, multinationals, corrupt, taxes, profit, profits
#
#    MGP_Proportion  \
# 0        0.119289
# 1        0.243655
# 2        0.032995
# 3        0.053299
# 4        0.121827
# 5        0.065990
# 6        0.083756
# 7        0.035533
# 8        0.002538
# 9        0.035533
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         MGP_Relevant_Tweets  \
# 0                                                                                                                                                                                                                                    [21, 58, 60, 81, 99, 101, 118, 125, 126, 129, 143, 146, 149, 152, 165, 177, 191, 194, 195, 205, 207, 214, 222, 235, 240, 245, 254, 260, 268, 270, 274, 279, 294, 298, 300, 302, 303, 313, 316, 319, 322, 328, 332, 341, 347, 374, 391]
# 1  [1, 2, 10, 13, 19, 27, 28, 38, 44, 45, 51, 60, 65, 69, 81, 82, 83, 87, 88, 91, 95, 98, 100, 105, 111, 113, 115, 120, 125, 126, 130, 135, 138, 148, 152, 154, 156, 158, 159, 163, 167, 168, 184, 185, 190, 194, 196, 205, 212, 228, 230, 231, 232, 234, 239, 241, 243, 249, 250, 257, 264, 266, 270, 275, 276, 280, 285, 287, 293, 299, 301, 304, 305, 315, 321, 322, 323, 332, 335, 338, 339, 342, 345, 348, 349, 352, 358, 367, 370, 372, 375, 384, 387, 389, 392, 393]
# 2                                                                                                                                                                                                                                                                                                                                                                                                            [50, 75, 98, 110, 114, 145, 261, 263, 264, 265, 266, 364, 377]
# 3                                                                                                                                                                                                                                                                                                                                                                     [30, 69, 92, 96, 171, 172, 199, 275, 305, 309, 312, 314, 316, 338, 359, 360, 364, 370, 371, 375, 379]
# 4                                                                                                                                                                                                                                     [5, 36, 46, 51, 84, 85, 88, 91, 95, 96, 105, 124, 136, 148, 173, 176, 180, 183, 184, 199, 204, 205, 213, 231, 239, 245, 254, 290, 297, 298, 300, 305, 309, 318, 321, 330, 336, 337, 340, 346, 356, 363, 365, 376, 377, 378, 384, 389]
# 5                                                                                                                                                                                                                                                                                                                                          [17, 44, 103, 127, 142, 153, 160, 235, 240, 248, 257, 270, 278, 284, 292, 295, 297, 310, 324, 335, 338, 353, 382, 384, 385, 390]
# 6                                                                                                                                                                                                                                                                                                         [25, 56, 64, 96, 103, 129, 140, 145, 149, 160, 180, 182, 191, 194, 199, 214, 234, 247, 272, 273, 283, 284, 289, 290, 321, 325, 328, 330, 337, 354, 355, 356, 386]
# 7                                                                                                                                                                                                                                                                                                                                                                                                         [21, 33, 66, 81, 94, 112, 200, 204, 254, 297, 305, 361, 381, 388]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [125]
# 9                                                                                                                                                                                                                                                                                                                                                                                                     [77, 127, 131, 171, 197, 204, 261, 270, 276, 374, 377, 385, 387, 392]
#
#    Deluzio_Proportion  \
# 0            0.094778
# 1            0.166344
# 2            0.160542
# 3            0.036750
# 4            0.176015
# 5            0.141199
# 6            0.071567
# 7            0.125725
# 8            0.054159
# 9            0.189555
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Deluzio_Relevant_Tweets
# 0                                                                                                                                                                                                                                             [13, 20, 28, 31, 37, 39, 60, 62, 97, 106, 112, 115, 116, 120, 129, 131, 169, 177, 178, 186, 195, 196, 200, 202, 235, 254, 295, 306, 309, 318, 332, 334, 341, 343, 354, 357, 371, 375, 378, 394, 398, 423, 442, 456, 457, 473, 478, 486, 488]
# 1                                                              [7, 13, 15, 19, 23, 25, 32, 36, 45, 52, 56, 60, 64, 67, 70, 82, 86, 95, 110, 111, 125, 126, 135, 138, 155, 157, 159, 160, 162, 163, 166, 175, 182, 184, 187, 188, 189, 195, 199, 207, 208, 211, 217, 223, 224, 236, 239, 243, 251, 256, 266, 268, 275, 283, 284, 289, 308, 322, 327, 332, 345, 346, 347, 361, 362, 366, 369, 375, 381, 386, 387, 396, 401, 410, 431, 432, 434, 435, 451, 453, 458, 467, 486, 487, 488, 499]
# 2                                                                   [10, 16, 24, 32, 42, 45, 67, 84, 91, 101, 107, 110, 117, 128, 138, 140, 153, 155, 163, 164, 165, 166, 175, 179, 183, 188, 218, 221, 222, 224, 225, 234, 236, 245, 246, 247, 249, 256, 272, 276, 277, 278, 279, 282, 284, 286, 289, 296, 297, 302, 303, 315, 319, 321, 325, 333, 351, 354, 355, 362, 387, 409, 419, 425, 443, 447, 451, 454, 459, 466, 470, 471, 472, 479, 480, 481, 482, 484, 487, 501, 502, 503, 512]
# 3                                                                                                                                                                                                                                                                                                                                                                                             [32, 73, 81, 110, 129, 135, 139, 160, 190, 195, 196, 225, 227, 228, 258, 275, 325, 340, 436]
# 4                                   [5, 10, 24, 27, 28, 31, 38, 42, 58, 60, 61, 72, 86, 87, 96, 97, 106, 112, 116, 128, 130, 131, 133, 140, 142, 157, 163, 164, 172, 173, 177, 178, 188, 196, 198, 201, 202, 225, 227, 234, 235, 254, 258, 261, 275, 283, 286, 287, 296, 297, 306, 309, 311, 318, 332, 334, 341, 351, 357, 359, 362, 369, 371, 375, 378, 394, 400, 404, 405, 413, 415, 416, 417, 419, 423, 425, 442, 446, 448, 455, 456, 457, 459, 473, 478, 490, 493, 494, 498, 502, 507]
# 5                                                                                                                               [1, 8, 20, 23, 24, 36, 40, 56, 72, 79, 81, 84, 89, 90, 91, 93, 98, 109, 120, 137, 154, 155, 157, 161, 173, 178, 192, 193, 200, 210, 213, 225, 230, 233, 241, 244, 265, 266, 271, 289, 292, 296, 303, 306, 321, 331, 337, 346, 352, 356, 357, 367, 368, 369, 392, 393, 396, 400, 407, 411, 414, 415, 435, 436, 438, 440, 443, 454, 456, 481, 487, 506, 516]
# 6                                                                                                                                                                                                                                                                                                      [10, 20, 28, 38, 60, 80, 104, 112, 115, 131, 169, 172, 202, 203, 226, 232, 257, 258, 261, 281, 295, 306, 318, 354, 357, 371, 378, 398, 423, 456, 457, 473, 478, 493, 494, 495, 496]
# 7                                                                                                                                                               [8, 32, 35, 42, 63, 64, 68, 69, 91, 94, 101, 102, 107, 110, 128, 151, 162, 164, 165, 167, 188, 191, 221, 224, 234, 246, 259, 269, 270, 272, 276, 281, 290, 293, 298, 300, 302, 306, 316, 323, 325, 326, 333, 355, 358, 374, 383, 386, 387, 388, 408, 418, 438, 443, 451, 454, 460, 468, 469, 470, 471, 479, 482, 484, 492]
# 8                                                                                                                                                                                                                                                                                                                                                    [8, 63, 68, 69, 91, 94, 150, 151, 162, 167, 223, 259, 263, 293, 298, 300, 325, 358, 408, 443, 445, 447, 451, 454, 460, 461, 470, 492]
# 9  [8, 12, 24, 29, 34, 35, 50, 53, 54, 58, 63, 64, 76, 85, 91, 92, 93, 99, 100, 101, 108, 109, 111, 119, 121, 127, 145, 151, 152, 162, 163, 164, 166, 167, 187, 188, 192, 198, 204, 205, 207, 214, 215, 216, 218, 221, 223, 229, 232, 233, 238, 246, 251, 252, 256, 259, 260, 281, 283, 296, 300, 305, 317, 322, 333, 342, 346, 377, 381, 385, 389, 400, 411, 419, 427, 429, 431, 438, 441, 443, 447, 448, 450, 454, 461, 462, 466, 470, 480, 481, 483, 484, 485, 488, 489, 504, 513, 516]

# %% [markdown]
# # Visualizing

# %%
def get_tweet_texts(tweet_indices, tweet_dataframe):
    # Retrieve 3 tweets from the index, if fewer than 3 exist include all
    sample_size = min(3, len(tweet_indices))
    np.random.seed(30)
    sampled_indices = np.random.choice(tweet_indices, size=sample_size, replace=False)
    tweets = tweet_dataframe.loc[sampled_indices, 'tweet_text_with_breaks'].tolist()
    # Concatenate tweet texts with a label before each tweet for clarity
    tweets_with_labels = [f"<strong>Ex. Tweet:</strong><br>{tweet}" for tweet in tweets]
    return "<br><br>".join(tweets_with_labels)

# Apply the function to each row and store the results in new columns
all_results_df['MGP_Tweet_Texts'] = all_results_df['MGP_Relevant_Tweets'].apply(lambda x: get_tweet_texts(x, mgp_tweets))
all_results_df['Deluzio_Tweet_Texts'] = all_results_df['Deluzio_Relevant_Tweets'].apply(lambda x: get_tweet_texts(x, deluzio_tweets))

# %%
import pandas as pd

# Initialize lists to store data
topics = []
candidates = []
Proportions = []
semantically_similar_words = []

# Iterate over each row in the original DataFrame to populate the lists
for i, row in all_results_df.iterrows():
    first_word = row['Semantically_Similar_Words'].split(', ')[0]  # Extract the first word for simplicity
    # Add entry for MGP
    topics.append(first_word)
    candidates.append('MGP')
    Proportions.append(row['MGP_Proportion'] if 'MGP_Proportion' in all_results_df.columns else 0)  # Default to 0 if column doesn't exist
    semantically_similar_words.append(row['Semantically_Similar_Words'])

    # Add entry for Deluzio
    topics.append(first_word)
    candidates.append('Deluzio')
    Proportions.append(row['Deluzio_Proportion'] if 'Deluzio_Proportion' in all_results_df.columns else 0)  # Default to 0 if column doesn't exist
    semantically_similar_words.append(row['Semantically_Similar_Words'])

# Create the new DataFrame
simplified_df = pd.DataFrame({
    'Topic': topics,
    'Candidate': candidates,
    'Proportion': Proportions,
    'Semantically_Similar_Words': semantically_similar_words
})

# Display the new DataFrame
print(simplified_df.head())
# Out:
#        Topic Candidate  Proportion  \
# 0    extreme       MGP    0.119289
# 1    extreme   Deluzio    0.094778
# 2  volunteer       MGP    0.243655
# 3  volunteer   Deluzio    0.166344
# 4     unions       MGP    0.032995
#
#                                                                                                                                                                                                                                                                                                                                                                            Semantically_Similar_Words
# 0  extreme, radical, extremist, extremists, extremism, dangerous, insanity, insane, chaos, violent, far-right, rightwing, right-wing, anti-choice, homophobic, bigot, bigoted, MAGA, violent, insurrection, xenophobic, fascists, oppressive, authoritarian, divisive, anti-gay, misogynistic, deranged, hateful, anti-democratic, anti-democracy, conspiracy, conspiratorial, QAnon, insurrectionist
# 1  extreme, radical, extremist, extremists, extremism, dangerous, insanity, insane, chaos, violent, far-right, rightwing, right-wing, anti-choice, homophobic, bigot, bigoted, MAGA, violent, insurrection, xenophobic, fascists, oppressive, authoritarian, divisive, anti-gay, misogynistic, deranged, hateful, anti-democratic, anti-democracy, conspiracy, conspiratorial, QAnon, insurrectionist
# 2                                                                             volunteer, volunteers, volunteering, register, donate, donations, donation, fundraiser, contribute, raise, join, canvass, canvasser, canvassers, knock, support, supporters, outreach, fundraising, participate, raising, donating, fundraise, pledge, contribution, contributions, organize, organizing, donor, donors
# 3                                                                             volunteer, volunteers, volunteering, register, donate, donations, donation, fundraiser, contribute, raise, join, canvass, canvasser, canvassers, knock, support, supporters, outreach, fundraising, participate, raising, donating, fundraise, pledge, contribution, contributions, organize, organizing, donor, donors
# 4                                                                                                                                                                                                                                                                                                                unions, union, unionize, solidarity, tradecraft, labor, collective, strike, striking

# %%
def insert_word_breaks(text, words_per_line=10):
    words = text.split(', ')
    # Insert a <br> tag after every 'words_per_line' words
    for i in range(words_per_line, len(words), words_per_line):
        words[i] = '<br>' + words[i]
    return ', '.join(words)

# Apply the function to the 'Semantically_Similar_Words' column
simplified_df['Semantically_Similar_Words'] = simplified_df['Semantically_Similar_Words'].apply(insert_word_breaks)

# %%
# Function to map sample tweets based on the topic and candidate
def map_sample_tweets(row, all_results_df):
    # Find the first word of the topic as the key
    key = row['Topic'].split(',')[0]

    # Find the corresponding row in all_results_df
    corresponding_row = all_results_df[all_results_df['Semantically_Similar_Words'].str.contains(key, regex=False)]

    # Check if the current row in simplified_df is for MGP or Deluzio and assign the sample tweets accordingly
    if row['Candidate'] == 'MGP':
        return corresponding_row['MGP_Tweet_Texts'].iloc[0] if not corresponding_row.empty else "No tweets available"
    elif row['Candidate'] == 'Deluzio':
        return corresponding_row['Deluzio_Tweet_Texts'].iloc[0] if not corresponding_row.empty else "No tweets available"

# Apply the function to the simplified_df to create a new column for sample tweets
simplified_df['Sample_Tweets'] = simplified_df.apply(map_sample_tweets, axis=1, all_results_df=all_results_df)

# Display the updated DataFrame to confirm the sample tweets have been added
print(simplified_df.head())
# Out:
#        Topic Candidate  Proportion  \
# 0    extreme       MGP    0.119289
# 1    extreme   Deluzio    0.094778
# 2  volunteer       MGP    0.243655
# 3  volunteer   Deluzio    0.166344
# 4     unions       MGP    0.032995
#
#                                                                                                                                                                                                                                                                                                                                                                                        Semantically_Similar_Words  \
# 0  extreme, radical, extremist, extremists, extremism, dangerous, insanity, insane, chaos, violent, <br>far-right, rightwing, right-wing, anti-choice, homophobic, bigot, bigoted, MAGA, violent, insurrection, <br>xenophobic, fascists, oppressive, authoritarian, divisive, anti-gay, misogynistic, deranged, hateful, anti-democratic, <br>anti-democracy, conspiracy, conspiratorial, QAnon, insurrectionist
# 1  extreme, radical, extremist, extremists, extremism, dangerous, insanity, insane, chaos, violent, <br>far-right, rightwing, right-wing, anti-choice, homophobic, bigot, bigoted, MAGA, violent, insurrection, <br>xenophobic, fascists, oppressive, authoritarian, divisive, anti-gay, misogynistic, deranged, hateful, anti-democratic, <br>anti-democracy, conspiracy, conspiratorial, QAnon, insurrectionist
# 2                                                                                 volunteer, volunteers, volunteering, register, donate, donations, donation, fundraiser, contribute, raise, <br>join, canvass, canvasser, canvassers, knock, support, supporters, outreach, fundraising, participate, <br>raising, donating, fundraise, pledge, contribution, contributions, organize, organizing, donor, donors
# 3                                                                                 volunteer, volunteers, volunteering, register, donate, donations, donation, fundraiser, contribute, raise, <br>join, canvass, canvasser, canvassers, knock, support, supporters, outreach, fundraising, participate, <br>raising, donating, fundraise, pledge, contribution, contributions, organize, organizing, donor, donors
# 4                                                                                                                                                                                                                                                                                                                            unions, union, unionize, solidarity, tradecraft, labor, collective, strike, striking
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Sample_Tweets
# 0                                                                                                                                                                    <strong>Ex. Tweet:</strong><br>Joe Kent has now pulled ahead of Herrera Beutler <br>and it appears he will be our opponent in <br>November. Kent will only add to the dysfunction <br>paralyzing our country. With your backing we can <br>reject extremism and support the common good. I <br>look forward to earning your support!<br><br><strong>Ex. Tweet:</strong><br>Extremists don’t pass bills – they obstruct <br>progress. There is too much at stake to elect <br>representatives who tout lies or sit on their <br>hands. We need legislators who can get sh!t done.<br><br><strong>Ex. Tweet:</strong><br>Help elect a pro-choice mother who works in the <br>trades & keep Republican extremist, Joe Kent out <br>of Congress
# 1  <strong>Ex. Tweet:</strong><br>My right-wing opponent wants to put an abortion <br>ban in the Constitution, and is on the record <br>opposing exceptions for rape and incest victims. <br>He and his pals Dr. Oz & Doug Mastriano are too <br>extreme for #PA17. Let's win this @JoshShapiroPA <br>@JohnFetterman<br><br><strong>Ex. Tweet:</strong><br>Here’s the world my extremist opponent Jeremy <br>Shaffer wants for western PA. He’s a threat to <br>our freedom, and you better believe I’m not going <br>to stand by and let him and Doug Mastriano take <br>away your right to choose. #PA17<br><br><strong>Ex. Tweet:</strong><br>Honored to be endorsed by @NARAL . You'll always <br>know where I stand on protecting your freedom to <br>choose. And I'm going to fight hard to protect <br>you from extremists like Doug Mastriano and my <br>opponent and their plans to attack your rights.
# 2                                                                                        <strong>Ex. Tweet:</strong><br>Thank you to everyone who has reached out about <br>volunteering for the campaign. No matter who I’m <br>running against, we’re going to need your help to <br>win in November! You can sign up on my website: <br>http://marieforcongress.com/volunteer/ or reach <br>out to volunteer@Marieforcongress.com<br><br><strong>Ex. Tweet:</strong><br>(3/3) I’m ready to #FlipWA03 and get to work on <br>the issues that affect our communities most <br>deeply. We’re counting on your grassroots support <br>to help us defeat Joe Kent and bring the voices <br>of working Washingtonians to Congress. Chip in <br>here: ​​<br><br><strong>Ex. Tweet:</strong><br>You're proud to be endorsed by someone who used <br>tax payer dollars to hold private donor dinners? <br>Seems right.
# 3                                                                              <strong>Ex. Tweet:</strong><br>#TeamDeluzio is powered by the people. No <br>corporate dark money. And I'm up against a <br>Republican who's dumped a million of his own $$$$ <br>to try to buy this seat. If you can manage, <br>please support our fight for the common good. <br>https://secure.actblue.com/donate/chris-deluzio-for-congress-social<br><br><strong>Ex. Tweet:</strong><br>No better way to kick off a union weekend of <br>action than with @AlleghenyLabor at the <br>@steelworkers ! These folks are fired up, ready <br>to fight for our common good, and knock doors <br>across #PA17 today. ✊<br><br><strong>Ex. Tweet:</strong><br>Despite the weather, #TeamDeluzio is putting the <br>work in! Shout out to all of our amazing <br>volunteers across #PA-17 who are fighting for our <br>common good.
# 4                  <strong>Ex. Tweet:</strong><br>Joe Kent says he's all about “Law &amp; Order” <br>but wants to defund the FBI &amp; local police. <br>Says he's pro worker, but is anti union. Says he <br>loves democracy, but won’t accept the 2020 <br>election results. These mental gymnastics are <br>gold medal worthy. 🥇<br><br><strong>Ex. Tweet:</strong><br>Do you enjoy having weekends off? Or a 40-hour <br>work week? Overtime pay? Workday breaks? Thank a <br>union member! This Labor Day, let’s celebrate the <br>workers who fought to secure the protections we <br>enjoy today. Let’s keep raising the bar.<br><br><strong>Ex. Tweet:</strong><br>Hello from Pacific County, where we’re having fun <br>in the rain at the South Bend Labor Day parade! <br>Our campaign is powered by volunteers like you. <br>Join us at our next event ➡️ <br>http://marieforcongress.com/volunteer/

# %%
# Add a column for quoted topics to the simplified DataFrame
simplified_df['Quoted_Topic'] = ['"' + topic + '"' for topic in simplified_df['Topic']]

# %%
from bokeh.models import ColumnDataSource, FactorRange, CustomJSTickFormatter, HoverTool
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import factor_cmap

# Initialize the notebook output for Bokeh
output_notebook()

# Create a list of tuples for each combination of quoted topic and candidate
factors = [(quoted_topic, candidate) for quoted_topic in simplified_df['Quoted_Topic'].unique() for candidate in simplified_df['Candidate'].unique()]

# Update the ColumnDataSource to include a 'factors' column that combines 'Quoted_Topic' and 'Candidate'
simplified_df['factors'] = [(quoted_topic, candidate) for quoted_topic, candidate in zip(simplified_df['Quoted_Topic'], simplified_df['Candidate'])]
source = ColumnDataSource(simplified_df)

# Define colors for each candidate
candidate_colors = {'MGP': '#008080', 'Deluzio': '#7BAFD4'}

# Create the figure with the updated x_range using the new factors
p = figure(x_range=FactorRange(*factors), height=600, width=1000, title="Candidate Tweet Proportions by Primary Topic",
           toolbar_location=None, tools="")

# Draw the bars with proper color mapping and legend
p.vbar(x='factors', top='Proportion', width=0.9, source=source, legend_field='Candidate',
       fill_color=factor_cmap('Candidate', palette=list(candidate_colors.values()), factors=list(candidate_colors.keys())))


# Adjust title and axis labels
p.title.text_font_size = '16pt'
p.xaxis.major_label_orientation = 1
p.xaxis.major_label_text_font_size = "12pt"

# Hover tool configuration
hover = HoverTool()
hover.tooltips = [
    ("Candidate", "@Candidate"),
    ("Topic", "@Quoted_Topic"),
    ("Proportion", "@Proportion{0.0%}"),
    ("Words Used in Search", "@Semantically_Similar_Words{safe}"),
    ("Sample Tweets", "@Sample_Tweets{safe}")
]
p.add_tools(hover)

# Aesthetic adjustments
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.yaxis.formatter = CustomJSTickFormatter(code="return (tick*100).toFixed(0) + '%'")

# Display the plot
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a5e40ad7-e03d-46d4-a37f-34f8658b8a37">Loading BokehJS ...</span>
#     </div>
#   <div id="dd231b3b-f413-48d6-a9a3-2fd5898c3557" data-root-id="p1171" style="display: contents;"></div>

# %%
all_results_df['MGP_Full_Tweets'] = None
all_results_df['Deluzio_Full_Tweets']= None

for index, row in all_results_df.iterrows():
    # Retrieve the list of tweet indexes for MGP
    tweet_indexes = row['MGP_Relevant_Tweets']
    
    # Use .loc to get the corresponding tweets' full text
    full_tweets = mgp_tweets.loc[tweet_indexes, 'tweet_text_with_breaks']
    
    # Store the full tweets' text in the new column, converting to list to avoid index alignment issues
    all_results_df.at[index, 'MGP_Full_Tweets'] = full_tweets.tolist()

for index, row in all_results_df.iterrows():
    # Retrieve the list of tweet indexes for MGP
    tweet_indexes = row['Deluzio_Relevant_Tweets']
    
    # Use .loc to get the corresponding tweets' full text
    full_tweets = delu_tweets.loc[tweet_indexes, 'tweet_text_with_breaks']
    
    # Store the full tweets' text in the new column, converting to list to avoid index alignment issues
    all_results_df.at[index, 'MGP_Full_Tweets'] = full_tweets.tolist()
